# %%
import torch
from torch import nn
import torch.backends.cudnn as cudnn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.optim.lr_scheduler import CosineAnnealingLR, MultiStepLR
import torchvision
from torchvision import transforms, utils, datasets

import os
import sys
if '/opt/ros/kinetic/lib/python2.7/dist-packages' in sys.path:
    sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
import cv2
import h5py
import PIL
import numpy as np
import random
import logging
import gdown
from zipfile import ZipFile
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Parameters

# %%
RATIO_VALIDATION_SPLIT = 0.1
BATCH_SIZE = 8
NUM_WROKERS = 4
INPUT_IMG_SIZE = (101, 101)
EPOCH = 50               # train the training data n times, to save time, we just train 1 epoch
LR = 0.001               # learning rate
DATASET_ROOT = './3-class_behavior-reflex'
MODELS_ROOT = './models'
CLASSES = np.loadtxt('class_id.txt', str, delimiter='\n')

# %% [markdown]
# ## Download dataset

# %%
train_dataset_url = 'https://drive.google.com/uc?id=10wJUsO2Eo6aOK-ay-UlBBlf1_Ba1LdTY'
train_dataset_name = '3-class_behavior-reflex'
if not os.path.isdir(train_dataset_name):
    gdown.download(train_dataset_url, output=train_dataset_name + '.zip', quiet=False)
    zip1 = ZipFile(train_dataset_name + '.zip')
    zip1.extractall(train_dataset_name)
    zip1.close()

print 'Finished downloading training dataset.'
# Out:
# Finished downloading training dataset.

# %% [markdown]
# ## Download pre-trained model

# %%
pretrain_model_url = 'https://drive.google.com/uc?id=1aSU1mg0qiFsgBw1p2-hd2bgv2WtQh2m_'
pretrain_model_name = 'trailnet_3class_real_vr_mix_color.h5'
if not os.path.isfile(os.path.join(MODELS_ROOT, pretrain_model_name)):
    if not os.path.isdir(MODELS_ROOT):
        os.mkdir(MODELS_ROOT)
    gdown.download(pretrain_model_url, output=os.path.join(MODELS_ROOT, pretrain_model_name), quiet=False)
    
print 'Finished downloading pre-trained model.'
# Out:
# Finished downloading pre-trained model.

# %% [markdown]
# ## Useful functions:
# dataset visualization and image loading function

# %%
def vis_img(batch_data):   
    # show images
    imgs = torchvision.utils.make_grid(batch_data)
    imgs = imgs / 2 + 0.5     # unnormalize
    npimgs = imgs.numpy()
    plt.rcParams['figure.figsize'] = [12, 5]
    plt.imshow(np.transpose(npimgs, (1, 2, 0)))

# %%
def load_images_from_folder(folder, classes):
    img_paths = []
    labels = []
    for class_id, class_name in enumerate(classes):
        class_folder = os.path.join(folder, class_name)
        for filename in os.listdir(class_folder):
            filename.lower().endswith(('.png', '.jpg', '.jpeg'))
            img_paths.append(os.path.join(class_folder, filename))
            labels.append(class_id)
    return img_paths, labels

# %% [markdown]
# ## Custom pytorch dataset class for Trailnet (load dataset from txt)

# %%
class TrailnetDataset(Dataset):
    def __init__(self, datalist_filename):
        classes = CLASSES
        
        self.img_list = []
        self.label_list = []
        
        txt = np.loadtxt(datalist_filename, str, delimiter='\n')
        for line in txt:
            p, l  = line.split()
            self.img_list.append(p)
            self.label_list.append(l)
        
        print '********** Dataset Info start **********\n'
        print 'Source: ', datalist_filename
        print 'Output classes: ', classes
        print 'Amount of images: ', len(txt)
        print '\n*********** Dataset Info end ***********\n'
        
        self.data_transform = transforms.Compose([ 
                                transforms.Resize(INPUT_IMG_SIZE), \
                                transforms.ToTensor(), \
                                transforms.Normalize(mean=[0.5, 0.5, 0.5], \
                                                     std=[1, 1, 1]), \
                                ])
        
    def __len__(self):
        return len(self.img_list)
    
    def collect_folders_from_dataset(self, dataset_root, classes):
        # Implement by BFS
        search_list = [dataset_root, ]
        dataset_folders = [] 
        while len(search_list) != 0:
            root = search_list.pop(0)
            if set(os.listdir(root)) == set(classes):
                dataset_folders.append(root)
            else:
                for folder in os.listdir(root):
                    path = os.path.join(root, folder)
                    if os.path.isdir(path):
                        search_list.append(path)
        return dataset_folders

    def __getitem__(self, index):
        'Generates one sample of data'
        # print self.img_list[index]
        # Select sample, then load data and get label
        path = self.img_list[index]
        img_raw = self.default_loader(path)
        x = self.data_transform(img_raw)
        y = torch.tensor(self.label_list[index])
        return x, y, path
    
    def pil_loader(self, path):
        with open(path, 'rb') as f:
            with PIL.Image.open(f) as img:
                return img.convert('RGB')

    def accimage_loader(self, path):
        try:
            return accimage.Image(path)
        except IOError:
            # Potentially a decoding problem, fall back to PIL.Image
            return pil_loader(path)

    def default_loader(self, path):
        if torchvision.get_image_backend() == 'accimage':
            return self.accimage_loader(path)
        else:
            return self.pil_loader(path)

# %% [markdown]
# ## Train / validation dataset declaration

# %%
train_dataset = TrailnetDataset(datalist_filename='train_dataset.txt')
val_dataset = TrailnetDataset(datalist_filename='validation_dataset.txt')

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=NUM_WROKERS, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, num_workers=NUM_WROKERS, shuffle=False)
# Out:
# ********** Dataset Info start **********
#
# Source:  train_dataset.txt
# Output classes:  ['L' 'S' 'R']
# Amount of images:  26922
#
# *********** Dataset Info end ***********
#
# ********** Dataset Info start **********
#
# Source:  validation_dataset.txt
# Output classes:  ['L' 'S' 'R']
# Amount of images:  2992
#
# *********** Dataset Info end ***********

# %% [markdown]
# ## Training and Testing function

# %%
def train(loader, model, criterion, optimizer, device, debug_steps=100, epoch=-1):
    model.train(True)
    running_loss = 0.0
    running_regression_loss = 0.0
    running_classification_loss = 0.0
    for i, data in enumerate(loader):
        images, labels, _path = data
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)  # TODO CHANGE BOXES
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i and i % debug_steps == 0:
            avg_loss = loss / debug_steps
            # logging.info("Epoch: {}, Step: {}, Average Loss: {:.4f}".format(epoch, i, avg_loss))
            print "Epoch: {}, Step: {}, Average Loss: {:.6f}".format(epoch, i, avg_loss)
            running_loss = 0.0

def test(loader, model, criterion, device):
    model.eval()
    running_loss = 0.0
    num = 0
    for _, data in enumerate(loader):
        images, labels, _path = data
        images = images.to(device)
        labels = labels.to(device)
        num += 1

        with torch.no_grad():
            outputs = model(images)
            loss = criterion(outputs, labels)

        running_loss += loss.item()
    return running_loss / num

# %% [markdown]
# ## Trailnet 3 class output model

# %%
class TrailNet3Class(nn.Module):
    def __init__(self):
        super(TrailNet3Class, self).__init__()
        # 1 input image channel, 6 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(3, 32, 4)
        self.pool1 = nn.MaxPool2d((2, 2), stride=2)
        self.conv2 = nn.Conv2d(32, 32, 4)
        self.pool2 = nn.MaxPool2d((2, 2), stride=2)
        self.conv3 = nn.Conv2d(32, 32, 4)
        self.pool3 = nn.MaxPool2d((2, 2), stride=2)
        self.conv4 = nn.Conv2d(32, 32, 4, padding=(2, 2))
        self.pool4 = nn.MaxPool2d((2, 2), stride=2)
        # an affine operation: y = Wx + b
        self.fc1 = nn.Linear(800, 200)
        self.fc2 = nn.Linear(200, 3)

    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = self.pool3(self.conv3(x)) 
        x = self.pool4(self.conv4(x))    
        # print 'x size: ', x.size()   
        x = x.view(-1, self.num_flat_features(x))
        # print 'x size: ', x.size()   
        x = self.fc1(x)
        x = self.fc2(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %%
def load_pretrained_model(model, filename='trailnet_3class_real_vr_mix_color.h5', use_cuda=True):
    if filename.lower().endswith('.h5'):
        state_dict = h5py.File(os.path.join(MODELS_ROOT,filename), 'r')
        model.load_state_dict({l : torch.from_numpy(np.array(v)).view_as(p) \
                     for k, v in state_dict.items() \
                     for l, p in model.named_parameters() if k in l})
    elif filename.lower().endswith('.pth'):
        state_dict = torch.load(os.path.join(MODELS_ROOT, filename))
        model.load_state_dict(state_dict)
        
    if torch.cuda.is_available() and use_cuda:
        cudnn.benchmark = True
        model.cuda()

# %%
model = TrailNet3Class()
load_pretrained_model(model)

# %% [markdown]
# ## Training process

# %%
last_epoch = -1
validation_epochs = 5

params = model.parameters()

checkpoint_folder = './models'
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params, lr=1e-3, momentum=0.9, weight_decay=5e-4)
scheduler = CosineAnnealingLR(optimizer, 120, last_epoch=last_epoch)
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

for epoch in range(last_epoch + 1, EPOCH):
    scheduler.step()
    train(train_loader, model, criterion, optimizer, \
          device=DEVICE, debug_steps=100, epoch=epoch)

    if epoch % validation_epochs == 0 or epoch == EPOCH - 1:
        val_loss = test(val_loader, model, criterion, DEVICE)
        # logging.info("Epoch: {}, ".format(epoch) + \
        #            "Validation Loss: {:.4f}".format(val_loss))
        print "Epoch: {}, Validation Loss: {:.6f}".format(epoch, val_loss)
        model_path = os.path.join(checkpoint_folder, \
                                  "{}_epoch{}_loss{:.5f}.pth".format('trailnet_3class', epoch, val_loss))
        torch.save(model.state_dict(), model_path)
        # logging.info("Saved model {}".format(model_path))
# Out:
# /usr/local/lib/python2.7/dist-packages/torch/optim/lr_scheduler.py:82: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule.See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch: 0, Step: 100, Average Loss: 0.000400
# Epoch: 0, Step: 200, Average Loss: 0.000006
# Epoch: 0, Step: 300, Average Loss: 0.000002
# Epoch: 0, Step: 400, Average Loss: 0.000006
# Epoch: 0, Step: 500, Average Loss: 0.000399
# Epoch: 0, Step: 600, Average Loss: 0.000002
# Epoch: 0, Step: 700, Average Loss: 0.000016
# Epoch: 0, Step: 800, Average Loss: 0.000019
# Epoch: 0, Step: 900, Average Loss: 0.000006
# Epoch: 0, Step: 1000, Average Loss: 0.000025
# Epoch: 0, Step: 1100, Average Loss: 0.000004
# Epoch: 0, Step: 1200, Average Loss: 0.000000
# Epoch: 0, Step: 1300, Average Loss: 0.000001
# Epoch: 0, Step: 1400, Average Loss: 0.000007
# Epoch: 0, Step: 1500, Average Loss: 0.000061
# Epoch: 0, Step: 1600, Average Loss: 0.000004
# Epoch: 0, Step: 1700, Average Loss: 0.000000
# Epoch: 0, Step: 1800, Average Loss: 0.000002
# Epoch: 0, Step: 1900, Average Loss: 0.000004
# Epoch: 0, Step: 2000, Average Loss: 0.000913
# Epoch: 0, Step: 2100, Average Loss: 0.000302
# Epoch: 0, Step: 2200, Average Loss: 0.000001
# Epoch: 0, Step: 2300, Average Loss: 0.000000
# Epoch: 0, Step: 2400, Average Loss: 0.000000
# Epoch: 0, Step: 2500, Average Loss: 0.000057
# Epoch: 0, Step: 2600, Average Loss: 0.000002
# Epoch: 0, Step: 2700, Average Loss: 0.000007
# Epoch: 0, Step: 2800, Average Loss: 0.000038
# Epoch: 0, Step: 2900, Average Loss: 0.000020
# Epoch: 0, Step: 3000, Average Loss: 0.000000
# Epoch: 0, Step: 3100, Average Loss: 0.000001
# Epoch: 0, Step: 3200, Average Loss: 0.000003
# Epoch: 0, Step: 3300, Average Loss: 0.000175
# Epoch: 0, Validation Loss: 0.021576
# Epoch: 1, Step: 100, Average Loss: 0.000001
# Epoch: 1, Step: 200, Average Loss: 0.000002
# Epoch: 1, Step: 300, Average Loss: 0.000001
# Epoch: 1, Step: 400, Average Loss: 0.000007
# Epoch: 1, Step: 500, Average Loss: 0.000000
# Epoch: 1, Step: 600, Average Loss: 0.000006
# Epoch: 1, Step: 700, Average Loss: 0.000005
# Epoch: 1, Step: 800, Average Loss: 0.000061
# Epoch: 1, Step: 900, Average Loss: 0.000978
# Epoch: 1, Step: 1000, Average Loss: 0.000001
# Epoch: 1, Step: 1100, Average Loss: 0.000003
# Epoch: 1, Step: 1200, Average Loss: 0.000000
# Epoch: 1, Step: 1300, Average Loss: 0.000005
# Epoch: 1, Step: 1400, Average Loss: 0.000009
# Epoch: 1, Step: 1500, Average Loss: 0.000048
# Epoch: 1, Step: 1600, Average Loss: 0.000001
# Epoch: 1, Step: 1700, Average Loss: 0.000000
# Epoch: 1, Step: 1800, Average Loss: 0.000082
# Epoch: 1, Step: 1900, Average Loss: 0.000000
# Epoch: 1, Step: 2000, Average Loss: 0.000006
# Epoch: 1, Step: 2100, Average Loss: 0.000001
# Epoch: 1, Step: 2200, Average Loss: 0.000000
# Epoch: 1, Step: 2300, Average Loss: 0.000002
# Epoch: 1, Step: 2400, Average Loss: 0.000006
# Epoch: 1, Step: 2500, Average Loss: 0.000006
# Epoch: 1, Step: 2600, Average Loss: 0.000000
# Epoch: 1, Step: 2700, Average Loss: 0.000000
# Epoch: 1, Step: 2800, Average Loss: 0.000001
# Epoch: 1, Step: 2900, Average Loss: 0.000000
# Epoch: 1, Step: 3000, Average Loss: 0.000007
# Epoch: 1, Step: 3100, Average Loss: 0.000005
# Epoch: 1, Step: 3200, Average Loss: 0.000001
# Epoch: 1, Step: 3300, Average Loss: 0.000001
# Epoch: 2, Step: 100, Average Loss: 0.000002
# Epoch: 2, Step: 200, Average Loss: 0.000000
# Epoch: 2, Step: 300, Average Loss: 0.000019
# Epoch: 2, Step: 400, Average Loss: 0.000000
# Epoch: 2, Step: 500, Average Loss: 0.000005
# Epoch: 2, Step: 600, Average Loss: 0.000001
# Epoch: 2, Step: 700, Average Loss: 0.000005
# Epoch: 2, Step: 800, Average Loss: 0.000002
# Epoch: 2, Step: 900, Average Loss: 0.000001
# Epoch: 2, Step: 1000, Average Loss: 0.000017
# Epoch: 2, Step: 1100, Average Loss: 0.002708
# Epoch: 2, Step: 1200, Average Loss: 0.000160
# Epoch: 2, Step: 1300, Average Loss: 0.000001
# Epoch: 2, Step: 1400, Average Loss: 0.000003
# Epoch: 2, Step: 1500, Average Loss: 0.000000
# Epoch: 2, Step: 1600, Average Loss: 0.000000
# Epoch: 2, Step: 1700, Average Loss: 0.000000
# Epoch: 2, Step: 1800, Average Loss: 0.000001
# Epoch: 2, Step: 1900, Average Loss: 0.000171
# Epoch: 2, Step: 2000, Average Loss: 0.000000
# Epoch: 2, Step: 2100, Average Loss: 0.000572
# Epoch: 2, Step: 2200, Average Loss: 0.000001
# Epoch: 2, Step: 2300, Average Loss: 0.000002
# Epoch: 2, Step: 2400, Average Loss: 0.000000
# Epoch: 2, Step: 2500, Average Loss: 0.000000
# Epoch: 2, Step: 2600, Average Loss: 0.000001
# Epoch: 2, Step: 2700, Average Loss: 0.000002
# Epoch: 2, Step: 2800, Average Loss: 0.000002
# Epoch: 2, Step: 2900, Average Loss: 0.000000
# Epoch: 2, Step: 3000, Average Loss: 0.000000
# Epoch: 2, Step: 3100, Average Loss: 0.000001
# Epoch: 2, Step: 3200, Average Loss: 0.000002
# Epoch: 2, Step: 3300, Average Loss: 0.002676
# Epoch: 3, Step: 100, Average Loss: 0.000001
# Epoch: 3, Step: 200, Average Loss: 0.000001
# Epoch: 3, Step: 300, Average Loss: 0.000002
# Epoch: 3, Step: 400, Average Loss: 0.000005
# Epoch: 3, Step: 500, Average Loss: 0.000000
# Epoch: 3, Step: 600, Average Loss: 0.000000
# Epoch: 3, Step: 700, Average Loss: 0.000000
# Epoch: 3, Step: 800, Average Loss: 0.000001
# Epoch: 3, Step: 900, Average Loss: 0.000001
# Epoch: 3, Step: 1000, Average Loss: 0.000001
# Epoch: 3, Step: 1100, Average Loss: 0.000000
# Epoch: 3, Step: 1200, Average Loss: 0.000003
# Epoch: 3, Step: 1300, Average Loss: 0.000010
# Epoch: 3, Step: 1400, Average Loss: 0.000000
# Epoch: 3, Step: 1500, Average Loss: 0.000001
# Epoch: 3, Step: 1600, Average Loss: 0.000001
# Epoch: 3, Step: 1700, Average Loss: 0.000000
# Epoch: 3, Step: 1800, Average Loss: 0.000001
# Epoch: 3, Step: 1900, Average Loss: 0.000000
# Epoch: 3, Step: 2000, Average Loss: 0.000001
# Epoch: 3, Step: 2100, Average Loss: 0.000001
# Epoch: 3, Step: 2200, Average Loss: 0.000002
# Epoch: 3, Step: 2300, Average Loss: 0.000000
# Epoch: 3, Step: 2400, Average Loss: 0.000000
# Epoch: 3, Step: 2500, Average Loss: 0.000000
# Epoch: 3, Step: 2600, Average Loss: 0.000000
# Epoch: 3, Step: 2700, Average Loss: 0.000002
# Epoch: 3, Step: 2800, Average Loss: 0.000005
# Epoch: 3, Step: 2900, Average Loss: 0.000001
# Epoch: 3, Step: 3000, Average Loss: 0.000001
# Epoch: 3, Step: 3100, Average Loss: 0.000003
# Epoch: 3, Step: 3200, Average Loss: 0.000004
# Epoch: 3, Step: 3300, Average Loss: 0.000000
# Epoch: 4, Step: 100, Average Loss: 0.000001
# Epoch: 4, Step: 200, Average Loss: 0.000000
# Epoch: 4, Step: 300, Average Loss: 0.000020
# Epoch: 4, Step: 400, Average Loss: 0.000000
# Epoch: 4, Step: 500, Average Loss: 0.000000
# Epoch: 4, Step: 600, Average Loss: 0.000001
# Epoch: 4, Step: 700, Average Loss: 0.000000
# Epoch: 4, Step: 800, Average Loss: 0.000000
# Epoch: 4, Step: 900, Average Loss: 0.000000
# Epoch: 4, Step: 1000, Average Loss: 0.000000
# Epoch: 4, Step: 1100, Average Loss: 0.000003
# Epoch: 4, Step: 1200, Average Loss: 0.000000
# Epoch: 4, Step: 1300, Average Loss: 0.000000
# Epoch: 4, Step: 1400, Average Loss: 0.000000
# Epoch: 4, Step: 1500, Average Loss: 0.000000
# Epoch: 4, Step: 1600, Average Loss: 0.000004
# Epoch: 4, Step: 1700, Average Loss: 0.000000
# Epoch: 4, Step: 1800, Average Loss: 0.000000
# Epoch: 4, Step: 1900, Average Loss: 0.000004
# Epoch: 4, Step: 2000, Average Loss: 0.000000
# Epoch: 4, Step: 2100, Average Loss: 0.000001
# Epoch: 4, Step: 2200, Average Loss: 0.000000
# Epoch: 4, Step: 2300, Average Loss: 0.000045
# Epoch: 4, Step: 2400, Average Loss: 0.000000
# Epoch: 4, Step: 2500, Average Loss: 0.000000
# Epoch: 4, Step: 2600, Average Loss: 0.000000
# Epoch: 4, Step: 2700, Average Loss: 0.000000
# Epoch: 4, Step: 2800, Average Loss: 0.000017
# Epoch: 4, Step: 2900, Average Loss: 0.000000
# Epoch: 4, Step: 3000, Average Loss: 0.000000
# Epoch: 4, Step: 3100, Average Loss: 0.000000
# Epoch: 4, Step: 3200, Average Loss: 0.000001
# Epoch: 4, Step: 3300, Average Loss: 0.000001
# Epoch: 5, Step: 100, Average Loss: 0.000004
# Epoch: 5, Step: 200, Average Loss: 0.000000
# Epoch: 5, Step: 300, Average Loss: 0.000000
# Epoch: 5, Step: 400, Average Loss: 0.000000
# Epoch: 5, Step: 500, Average Loss: 0.000000
# Epoch: 5, Step: 600, Average Loss: 0.000001
# Epoch: 5, Step: 700, Average Loss: 0.000000
# Epoch: 5, Step: 800, Average Loss: 0.000000
# Epoch: 5, Step: 900, Average Loss: 0.000000
# Epoch: 5, Step: 1000, Average Loss: 0.000003
# Epoch: 5, Step: 1100, Average Loss: 0.000000
# Epoch: 5, Step: 1200, Average Loss: 0.000000
# Epoch: 5, Step: 1300, Average Loss: 0.000000
# Epoch: 5, Step: 1400, Average Loss: 0.000001
# Epoch: 5, Step: 1500, Average Loss: 0.000000
# Epoch: 5, Step: 1600, Average Loss: 0.000000
# Epoch: 5, Step: 1700, Average Loss: 0.000002
# Epoch: 5, Step: 1800, Average Loss: 0.000003
# Epoch: 5, Step: 1900, Average Loss: 0.000000
# Epoch: 5, Step: 2000, Average Loss: 0.000000
# Epoch: 5, Step: 2100, Average Loss: 0.000002
# Epoch: 5, Step: 2200, Average Loss: 0.000189
# Epoch: 5, Step: 2300, Average Loss: 0.000001
# Epoch: 5, Step: 2400, Average Loss: 0.000001
# Epoch: 5, Step: 2500, Average Loss: 0.000001
# Epoch: 5, Step: 2600, Average Loss: 0.000003
# Epoch: 5, Step: 2700, Average Loss: 0.000000
# Epoch: 5, Step: 2800, Average Loss: 0.000281
# Epoch: 5, Step: 2900, Average Loss: 0.000000
# Epoch: 5, Step: 3000, Average Loss: 0.000009
# Epoch: 5, Step: 3100, Average Loss: 0.000003
# Epoch: 5, Step: 3200, Average Loss: 0.000011
# Epoch: 5, Step: 3300, Average Loss: 0.000024
# Epoch: 5, Validation Loss: 0.001287
# Epoch: 6, Step: 100, Average Loss: 0.000001
# Epoch: 6, Step: 200, Average Loss: 0.000000
# Epoch: 6, Step: 300, Average Loss: 0.000001
# Epoch: 6, Step: 400, Average Loss: 0.000000
# Epoch: 6, Step: 500, Average Loss: 0.000003
# Epoch: 6, Step: 600, Average Loss: 0.000000
# Epoch: 6, Step: 700, Average Loss: 0.000000
# Epoch: 6, Step: 800, Average Loss: 0.000000
# Epoch: 6, Step: 900, Average Loss: 0.000011
# Epoch: 6, Step: 1000, Average Loss: 0.000000
# Epoch: 6, Step: 1100, Average Loss: 0.000000
# Epoch: 6, Step: 1200, Average Loss: 0.000000
# Epoch: 6, Step: 1300, Average Loss: 0.000000
# Epoch: 6, Step: 1400, Average Loss: 0.000000
# Epoch: 6, Step: 1500, Average Loss: 0.000190
# Epoch: 6, Step: 1600, Average Loss: 0.000000
# Epoch: 6, Step: 1700, Average Loss: 0.000004
# Epoch: 6, Step: 1800, Average Loss: 0.000000
# Epoch: 6, Step: 1900, Average Loss: 0.000004
# Epoch: 6, Step: 2000, Average Loss: 0.000000
# Epoch: 6, Step: 2100, Average Loss: 0.000000
# Epoch: 6, Step: 2200, Average Loss: 0.000004
# Epoch: 6, Step: 2300, Average Loss: 0.000000
# Epoch: 6, Step: 2400, Average Loss: 0.000000
# Epoch: 6, Step: 2500, Average Loss: 0.000001
# Epoch: 6, Step: 2600, Average Loss: 0.000000
# Epoch: 6, Step: 2700, Average Loss: 0.000000
# Epoch: 6, Step: 2800, Average Loss: 0.000000
# Epoch: 6, Step: 2900, Average Loss: 0.000000
# Epoch: 6, Step: 3000, Average Loss: 0.000000
# Epoch: 6, Step: 3100, Average Loss: 0.000000
# Epoch: 6, Step: 3200, Average Loss: 0.000000
# Epoch: 6, Step: 3300, Average Loss: 0.000000
# Epoch: 7, Step: 100, Average Loss: 0.000000
# Epoch: 7, Step: 200, Average Loss: 0.000000
# Epoch: 7, Step: 300, Average Loss: 0.000001
# Epoch: 7, Step: 400, Average Loss: 0.000000
# Epoch: 7, Step: 500, Average Loss: 0.000000
# Epoch: 7, Step: 600, Average Loss: 0.000000
# Epoch: 7, Step: 700, Average Loss: 0.000000
# Epoch: 7, Step: 800, Average Loss: 0.000000
# Epoch: 7, Step: 900, Average Loss: 0.000000
# Epoch: 7, Step: 1000, Average Loss: 0.000000
# Epoch: 7, Step: 1100, Average Loss: 0.000000
# Epoch: 7, Step: 1200, Average Loss: 0.000000
# Epoch: 7, Step: 1300, Average Loss: 0.000000
# Epoch: 7, Step: 1400, Average Loss: 0.000000
# Epoch: 7, Step: 1500, Average Loss: 0.000000
# Epoch: 7, Step: 1600, Average Loss: 0.000000
# Epoch: 7, Step: 1700, Average Loss: 0.000000
# Epoch: 7, Step: 1800, Average Loss: 0.000877
# Epoch: 7, Step: 1900, Average Loss: 0.000000
# Epoch: 7, Step: 2000, Average Loss: 0.000000
# Epoch: 7, Step: 2100, Average Loss: 0.000000
# Epoch: 7, Step: 2200, Average Loss: 0.000000
# Epoch: 7, Step: 2300, Average Loss: 0.000532
# Epoch: 7, Step: 2400, Average Loss: 0.000000
# Epoch: 7, Step: 2500, Average Loss: 0.000000
# Epoch: 7, Step: 2600, Average Loss: 0.000000
# Epoch: 7, Step: 2700, Average Loss: 0.000000
# Epoch: 7, Step: 2800, Average Loss: 0.000000
# Epoch: 7, Step: 2900, Average Loss: 0.000001
# Epoch: 7, Step: 3000, Average Loss: 0.000005
# Epoch: 7, Step: 3100, Average Loss: 0.000000
# Epoch: 7, Step: 3200, Average Loss: 0.000000
# Epoch: 7, Step: 3300, Average Loss: 0.000000
# Epoch: 8, Step: 100, Average Loss: 0.000000
# Epoch: 8, Step: 200, Average Loss: 0.000000
# Epoch: 8, Step: 300, Average Loss: 0.000000
# Epoch: 8, Step: 400, Average Loss: 0.000000
# Epoch: 8, Step: 500, Average Loss: 0.000000
# Epoch: 8, Step: 600, Average Loss: 0.000000
# Epoch: 8, Step: 700, Average Loss: 0.000000
# Epoch: 8, Step: 800, Average Loss: 0.000030
# Epoch: 8, Step: 900, Average Loss: 0.000000
# Epoch: 8, Step: 1000, Average Loss: 0.000000
# Epoch: 8, Step: 1100, Average Loss: 0.000359
# Epoch: 8, Step: 1200, Average Loss: 0.000000
# Epoch: 8, Step: 1300, Average Loss: 0.000000
# Epoch: 8, Step: 1400, Average Loss: 0.000000
# Epoch: 8, Step: 1500, Average Loss: 0.000000
# Epoch: 8, Step: 1600, Average Loss: 0.000000
# Epoch: 8, Step: 1700, Average Loss: 0.000000
# Epoch: 8, Step: 1800, Average Loss: 0.000000
# Epoch: 8, Step: 1900, Average Loss: 0.000000
# Epoch: 8, Step: 2000, Average Loss: 0.000000
# Epoch: 8, Step: 2100, Average Loss: 0.000000
# Epoch: 8, Step: 2200, Average Loss: 0.000000
# Epoch: 8, Step: 2300, Average Loss: 0.000000
# Epoch: 8, Step: 2400, Average Loss: 0.000000
# Epoch: 8, Step: 2500, Average Loss: 0.000000
# Epoch: 8, Step: 2600, Average Loss: 0.000000
# Epoch: 8, Step: 2700, Average Loss: 0.000001
# Epoch: 8, Step: 2800, Average Loss: 0.000000
# Epoch: 8, Step: 2900, Average Loss: 0.000000
# Epoch: 8, Step: 3000, Average Loss: 0.000004
# Epoch: 8, Step: 3100, Average Loss: 0.000002
# Epoch: 8, Step: 3200, Average Loss: 0.000001
# Epoch: 8, Step: 3300, Average Loss: 0.000000
# Epoch: 9, Step: 100, Average Loss: 0.000002
# Epoch: 9, Step: 200, Average Loss: 0.000001
# Epoch: 9, Step: 300, Average Loss: 0.000000
# Epoch: 9, Step: 400, Average Loss: 0.000000
# Epoch: 9, Step: 500, Average Loss: 0.000000
# Epoch: 9, Step: 600, Average Loss: 0.000003
# Epoch: 9, Step: 700, Average Loss: 0.000000
# Epoch: 9, Step: 800, Average Loss: 0.000000
# Epoch: 9, Step: 900, Average Loss: 0.000000
# Epoch: 9, Step: 1000, Average Loss: 0.000008
# Epoch: 9, Step: 1100, Average Loss: 0.000000
# Epoch: 9, Step: 1200, Average Loss: 0.000000
# Epoch: 9, Step: 1300, Average Loss: 0.000001
# Epoch: 9, Step: 1400, Average Loss: 0.000000
# Epoch: 9, Step: 1500, Average Loss: 0.000000
# Epoch: 9, Step: 1600, Average Loss: 0.000000
# Epoch: 9, Step: 1700, Average Loss: 0.000003
# Epoch: 9, Step: 1800, Average Loss: 0.000000
# Epoch: 9, Step: 1900, Average Loss: 0.000001
# Epoch: 9, Step: 2000, Average Loss: 0.000000
# Epoch: 9, Step: 2100, Average Loss: 0.000000
# Epoch: 9, Step: 2200, Average Loss: 0.000000
# Epoch: 9, Step: 2300, Average Loss: 0.000004
# Epoch: 9, Step: 2400, Average Loss: 0.000002
# Epoch: 9, Step: 2500, Average Loss: 0.000000
# Epoch: 9, Step: 2600, Average Loss: 0.000000
# Epoch: 9, Step: 2700, Average Loss: 0.000000
# Epoch: 9, Step: 2800, Average Loss: 0.000023
# Epoch: 9, Step: 2900, Average Loss: 0.000000
# Epoch: 9, Step: 3000, Average Loss: 0.000001
# Epoch: 9, Step: 3100, Average Loss: 0.000000
# Epoch: 9, Step: 3200, Average Loss: 0.000000
# Epoch: 9, Step: 3300, Average Loss: 0.000000
# Epoch: 10, Step: 100, Average Loss: 0.000008
# Epoch: 10, Step: 200, Average Loss: 0.000003
# Epoch: 10, Step: 300, Average Loss: 0.000000
# Epoch: 10, Step: 400, Average Loss: 0.000000
# Epoch: 10, Step: 500, Average Loss: 0.000000
# Epoch: 10, Step: 600, Average Loss: 0.000000
# Epoch: 10, Step: 700, Average Loss: 0.000000
# Epoch: 10, Step: 800, Average Loss: 0.000000
# Epoch: 10, Step: 900, Average Loss: 0.000000
# Epoch: 10, Step: 1000, Average Loss: 0.000000
# Epoch: 10, Step: 1100, Average Loss: 0.000000
# Epoch: 10, Step: 1200, Average Loss: 0.000057
# Epoch: 10, Step: 1300, Average Loss: 0.000000
# Epoch: 10, Step: 1400, Average Loss: 0.000001
# Epoch: 10, Step: 1500, Average Loss: 0.000000
# Epoch: 10, Step: 1600, Average Loss: 0.000003
# Epoch: 10, Step: 1700, Average Loss: 0.000001
# Epoch: 10, Step: 1800, Average Loss: 0.000000
# Epoch: 10, Step: 1900, Average Loss: 0.000001
# Epoch: 10, Step: 2000, Average Loss: 0.000000
# Epoch: 10, Step: 2100, Average Loss: 0.000000
# Epoch: 10, Step: 2200, Average Loss: 0.000000
# Epoch: 10, Step: 2300, Average Loss: 0.000003
# Epoch: 10, Step: 2400, Average Loss: 0.000000
# Epoch: 10, Step: 2500, Average Loss: 0.000000
# Epoch: 10, Step: 2600, Average Loss: 0.000000
# Epoch: 10, Step: 2700, Average Loss: 0.000000
# Epoch: 10, Step: 2800, Average Loss: 0.001300
# Epoch: 10, Step: 2900, Average Loss: 0.000000
# Epoch: 10, Step: 3000, Average Loss: 0.000000
# Epoch: 10, Step: 3100, Average Loss: 0.000000
# Epoch: 10, Step: 3200, Average Loss: 0.000000
# Epoch: 10, Step: 3300, Average Loss: 0.000000
# Epoch: 10, Validation Loss: 0.000615
# Epoch: 11, Step: 100, Average Loss: 0.000000
# Epoch: 11, Step: 200, Average Loss: 0.000000
# Epoch: 11, Step: 300, Average Loss: 0.000000
# Epoch: 11, Step: 400, Average Loss: 0.000002
# Epoch: 11, Step: 500, Average Loss: 0.000000
# Epoch: 11, Step: 600, Average Loss: 0.000000
# Epoch: 11, Step: 700, Average Loss: 0.000002
# Epoch: 11, Step: 800, Average Loss: 0.000000
# Epoch: 11, Step: 900, Average Loss: 0.000000
# Epoch: 11, Step: 1000, Average Loss: 0.000006
# Epoch: 11, Step: 1100, Average Loss: 0.000000
# Epoch: 11, Step: 1200, Average Loss: 0.000000
# Epoch: 11, Step: 1300, Average Loss: 0.000014
# Epoch: 11, Step: 1400, Average Loss: 0.000000
# Epoch: 11, Step: 1500, Average Loss: 0.000000
# Epoch: 11, Step: 1600, Average Loss: 0.000000
# Epoch: 11, Step: 1700, Average Loss: 0.000000
# Epoch: 11, Step: 1800, Average Loss: 0.000000
# Epoch: 11, Step: 1900, Average Loss: 0.000002
# Epoch: 11, Step: 2000, Average Loss: 0.000000
# Epoch: 11, Step: 2100, Average Loss: 0.000000
# Epoch: 11, Step: 2200, Average Loss: 0.000000
# Epoch: 11, Step: 2300, Average Loss: 0.000022
# Epoch: 11, Step: 2400, Average Loss: 0.000000
# Epoch: 11, Step: 2500, Average Loss: 0.000000
# Epoch: 11, Step: 2600, Average Loss: 0.000000
# Epoch: 11, Step: 2700, Average Loss: 0.000000
# Epoch: 11, Step: 2800, Average Loss: 0.000000
# Epoch: 11, Step: 2900, Average Loss: 0.000028
# Epoch: 11, Step: 3000, Average Loss: 0.000001
# Epoch: 11, Step: 3100, Average Loss: 0.000000
# Epoch: 11, Step: 3200, Average Loss: 0.000000
# Epoch: 11, Step: 3300, Average Loss: 0.000000
# Epoch: 12, Step: 100, Average Loss: 0.000000
# Epoch: 12, Step: 200, Average Loss: 0.000000
# Epoch: 12, Step: 300, Average Loss: 0.000000
# Epoch: 12, Step: 400, Average Loss: 0.000001
# Epoch: 12, Step: 500, Average Loss: 0.000000
# Epoch: 12, Step: 600, Average Loss: 0.000000
# Epoch: 12, Step: 700, Average Loss: 0.000000
# Epoch: 12, Step: 800, Average Loss: 0.000002
# Epoch: 12, Step: 900, Average Loss: 0.000001
# Epoch: 12, Step: 1000, Average Loss: 0.000000
# Epoch: 12, Step: 1100, Average Loss: 0.000000
# Epoch: 12, Step: 1200, Average Loss: 0.000016
# Epoch: 12, Step: 1300, Average Loss: 0.000000
# Epoch: 12, Step: 1400, Average Loss: 0.000000
# Epoch: 12, Step: 1500, Average Loss: 0.000178
# Epoch: 12, Step: 1600, Average Loss: 0.000000
# Epoch: 12, Step: 1700, Average Loss: 0.000000
# Epoch: 12, Step: 1800, Average Loss: 0.000002
# Epoch: 12, Step: 1900, Average Loss: 0.000000
# Epoch: 12, Step: 2000, Average Loss: 0.000000
# Epoch: 12, Step: 2100, Average Loss: 0.000000
# Epoch: 12, Step: 2200, Average Loss: 0.000001
# Epoch: 12, Step: 2300, Average Loss: 0.000000
# Epoch: 12, Step: 2400, Average Loss: 0.000001
# Epoch: 12, Step: 2500, Average Loss: 0.000000
# Epoch: 12, Step: 2600, Average Loss: 0.000007
# Epoch: 12, Step: 2700, Average Loss: 0.000001
# Epoch: 12, Step: 2800, Average Loss: 0.000001
# Epoch: 12, Step: 2900, Average Loss: 0.000000
# Epoch: 12, Step: 3000, Average Loss: 0.000000
# Epoch: 12, Step: 3100, Average Loss: 0.000000
# Epoch: 12, Step: 3200, Average Loss: 0.000001
# Epoch: 12, Step: 3300, Average Loss: 0.000000
# Epoch: 13, Step: 100, Average Loss: 0.000000
# Epoch: 13, Step: 200, Average Loss: 0.000000
# Epoch: 13, Step: 300, Average Loss: 0.000000
# Epoch: 13, Step: 400, Average Loss: 0.000000
# Epoch: 13, Step: 500, Average Loss: 0.000000
# Epoch: 13, Step: 600, Average Loss: 0.000000
# Epoch: 13, Step: 700, Average Loss: 0.000000
# Epoch: 13, Step: 800, Average Loss: 0.000000
# Epoch: 13, Step: 900, Average Loss: 0.000000
# Epoch: 13, Step: 1000, Average Loss: 0.000000
# Epoch: 13, Step: 1100, Average Loss: 0.000002
# Epoch: 13, Step: 1200, Average Loss: 0.000000
# Epoch: 13, Step: 1300, Average Loss: 0.000000
# Epoch: 13, Step: 1400, Average Loss: 0.000010
# Epoch: 13, Step: 1500, Average Loss: 0.000000
# Epoch: 13, Step: 1600, Average Loss: 0.000000
# Epoch: 13, Step: 1700, Average Loss: 0.000000
# Epoch: 13, Step: 1800, Average Loss: 0.000000
# Epoch: 13, Step: 1900, Average Loss: 0.000000
# Epoch: 13, Step: 2000, Average Loss: 0.000000
# Epoch: 13, Step: 2100, Average Loss: 0.000000
# Epoch: 13, Step: 2200, Average Loss: 0.000000
# Epoch: 13, Step: 2300, Average Loss: 0.000000
# Epoch: 13, Step: 2400, Average Loss: 0.000000
# Epoch: 13, Step: 2500, Average Loss: 0.000000
# Epoch: 13, Step: 2600, Average Loss: 0.000000
# Epoch: 13, Step: 2700, Average Loss: 0.000000
# Epoch: 13, Step: 2800, Average Loss: 0.000000
# Epoch: 13, Step: 2900, Average Loss: 0.000000
# Epoch: 13, Step: 3000, Average Loss: 0.000000
# Epoch: 13, Step: 3100, Average Loss: 0.000001
# Epoch: 13, Step: 3200, Average Loss: 0.000000
# Epoch: 13, Step: 3300, Average Loss: 0.000001
# Epoch: 14, Step: 100, Average Loss: 0.000000
# Epoch: 14, Step: 200, Average Loss: 0.000000
# Epoch: 14, Step: 300, Average Loss: 0.000000
# Epoch: 14, Step: 400, Average Loss: 0.000000
# Epoch: 14, Step: 500, Average Loss: 0.000000
# Epoch: 14, Step: 600, Average Loss: 0.000001
# Epoch: 14, Step: 700, Average Loss: 0.000000
# Epoch: 14, Step: 800, Average Loss: 0.000000
# Epoch: 14, Step: 900, Average Loss: 0.000003
# Epoch: 14, Step: 1000, Average Loss: 0.000001
# Epoch: 14, Step: 1100, Average Loss: 0.000000
# Epoch: 14, Step: 1200, Average Loss: 0.000000
# Epoch: 14, Step: 1300, Average Loss: 0.000000
# Epoch: 14, Step: 1400, Average Loss: 0.000005
# Epoch: 14, Step: 1500, Average Loss: 0.000000
# Epoch: 14, Step: 1600, Average Loss: 0.000000
# Epoch: 14, Step: 1700, Average Loss: 0.000004
# Epoch: 14, Step: 1800, Average Loss: 0.000000
# Epoch: 14, Step: 1900, Average Loss: 0.000000
# Epoch: 14, Step: 2000, Average Loss: 0.000000
# Epoch: 14, Step: 2100, Average Loss: 0.000000
# Epoch: 14, Step: 2200, Average Loss: 0.000095
# Epoch: 14, Step: 2300, Average Loss: 0.000000
# Epoch: 14, Step: 2400, Average Loss: 0.000000
# Epoch: 14, Step: 2500, Average Loss: 0.000000
# Epoch: 14, Step: 2600, Average Loss: 0.000000
# Epoch: 14, Step: 2700, Average Loss: 0.000000
# Epoch: 14, Step: 2800, Average Loss: 0.000248
# Epoch: 14, Step: 2900, Average Loss: 0.000000
# Epoch: 14, Step: 3000, Average Loss: 0.000000
# Epoch: 14, Step: 3100, Average Loss: 0.000000
# Epoch: 14, Step: 3200, Average Loss: 0.000000
# Epoch: 14, Step: 3300, Average Loss: 0.000000
# Epoch: 15, Step: 100, Average Loss: 0.000000
# Epoch: 15, Step: 200, Average Loss: 0.000000
# Epoch: 15, Step: 300, Average Loss: 0.000000
# Epoch: 15, Step: 400, Average Loss: 0.000000
# Epoch: 15, Step: 500, Average Loss: 0.000000
# Epoch: 15, Step: 600, Average Loss: 0.000000
# Epoch: 15, Step: 700, Average Loss: 0.000000
# Epoch: 15, Step: 800, Average Loss: 0.000002
# Epoch: 15, Step: 900, Average Loss: 0.000000
# Epoch: 15, Step: 1000, Average Loss: 0.000000
# Epoch: 15, Step: 1100, Average Loss: 0.000000
# Epoch: 15, Step: 1200, Average Loss: 0.000000
# Epoch: 15, Step: 1300, Average Loss: 0.000000
# Epoch: 15, Step: 1400, Average Loss: 0.000000
# Epoch: 15, Step: 1500, Average Loss: 0.000000
# Epoch: 15, Step: 1600, Average Loss: 0.000001
# Epoch: 15, Step: 1700, Average Loss: 0.000000
# Epoch: 15, Step: 1800, Average Loss: 0.000000
# Epoch: 15, Step: 1900, Average Loss: 0.000000
# Epoch: 15, Step: 2000, Average Loss: 0.000004
# Epoch: 15, Step: 2100, Average Loss: 0.000000
# Epoch: 15, Step: 2200, Average Loss: 0.000000
# Epoch: 15, Step: 2300, Average Loss: 0.000000
# Epoch: 15, Step: 2400, Average Loss: 0.000001
# Epoch: 15, Step: 2500, Average Loss: 0.000000
# Epoch: 15, Step: 2600, Average Loss: 0.000000
# Epoch: 15, Step: 2700, Average Loss: 0.000096
# Epoch: 15, Step: 2800, Average Loss: 0.000000
# Epoch: 15, Step: 2900, Average Loss: 0.000000
# Epoch: 15, Step: 3000, Average Loss: 0.000001
# Epoch: 15, Step: 3100, Average Loss: 0.000008
# Epoch: 15, Step: 3200, Average Loss: 0.000000
# Epoch: 15, Step: 3300, Average Loss: 0.000000
# Epoch: 15, Validation Loss: 0.000430
# Epoch: 16, Step: 100, Average Loss: 0.000001
# Epoch: 16, Step: 200, Average Loss: 0.000000
# Epoch: 16, Step: 300, Average Loss: 0.000000
# Epoch: 16, Step: 400, Average Loss: 0.000000
# Epoch: 16, Step: 500, Average Loss: 0.000000
# Epoch: 16, Step: 600, Average Loss: 0.000001
# Epoch: 16, Step: 700, Average Loss: 0.000000
# Epoch: 16, Step: 800, Average Loss: 0.000000
# Epoch: 16, Step: 900, Average Loss: 0.000000
# Epoch: 16, Step: 1000, Average Loss: 0.000033
# Epoch: 16, Step: 1100, Average Loss: 0.000000
# Epoch: 16, Step: 1200, Average Loss: 0.000000
# Epoch: 16, Step: 1300, Average Loss: 0.000000
# Epoch: 16, Step: 1400, Average Loss: 0.000001
# Epoch: 16, Step: 1500, Average Loss: 0.000000
# Epoch: 16, Step: 1600, Average Loss: 0.000000
# Epoch: 16, Step: 1700, Average Loss: 0.000000
# Epoch: 16, Step: 1800, Average Loss: 0.000003
# Epoch: 16, Step: 1900, Average Loss: 0.000000
# Epoch: 16, Step: 2000, Average Loss: 0.000002
# Epoch: 16, Step: 2100, Average Loss: 0.000097
# Epoch: 16, Step: 2200, Average Loss: 0.000012
# Epoch: 16, Step: 2300, Average Loss: 0.000001
# Epoch: 16, Step: 2400, Average Loss: 0.000000
# Epoch: 16, Step: 2500, Average Loss: 0.000000
# Epoch: 16, Step: 2600, Average Loss: 0.000000
# Epoch: 16, Step: 2700, Average Loss: 0.000001
# Epoch: 16, Step: 2800, Average Loss: 0.000000
# Epoch: 16, Step: 2900, Average Loss: 0.000001
# Epoch: 16, Step: 3000, Average Loss: 0.000000
# Epoch: 16, Step: 3100, Average Loss: 0.000000
# Epoch: 16, Step: 3200, Average Loss: 0.000000
# Epoch: 16, Step: 3300, Average Loss: 0.000001
# Epoch: 17, Step: 100, Average Loss: 0.000001
# Epoch: 17, Step: 200, Average Loss: 0.000000
# Epoch: 17, Step: 300, Average Loss: 0.000000
# Epoch: 17, Step: 400, Average Loss: 0.000000
# Epoch: 17, Step: 500, Average Loss: 0.000000
# Epoch: 17, Step: 600, Average Loss: 0.000001
# Epoch: 17, Step: 700, Average Loss: 0.000000
# Epoch: 17, Step: 800, Average Loss: 0.000000
# Epoch: 17, Step: 900, Average Loss: 0.000000
# Epoch: 17, Step: 1000, Average Loss: 0.000000
# Epoch: 17, Step: 1100, Average Loss: 0.000004
# Epoch: 17, Step: 1200, Average Loss: 0.000000
# Epoch: 17, Step: 1300, Average Loss: 0.000000
# Epoch: 17, Step: 1400, Average Loss: 0.000000
# Epoch: 17, Step: 1500, Average Loss: 0.000001
# Epoch: 17, Step: 1600, Average Loss: 0.000000
# Epoch: 17, Step: 1700, Average Loss: 0.000000
# Epoch: 17, Step: 1800, Average Loss: 0.000001
# Epoch: 17, Step: 1900, Average Loss: 0.000000
# Epoch: 17, Step: 2000, Average Loss: 0.000001
# Epoch: 17, Step: 2100, Average Loss: 0.000000
# Epoch: 17, Step: 2200, Average Loss: 0.000000
# Epoch: 17, Step: 2300, Average Loss: 0.000000
# Epoch: 17, Step: 2400, Average Loss: 0.000000
# Epoch: 17, Step: 2500, Average Loss: 0.000000
# Epoch: 17, Step: 2600, Average Loss: 0.000001
# Epoch: 17, Step: 2700, Average Loss: 0.000001
# Epoch: 17, Step: 2800, Average Loss: 0.000000
# Epoch: 17, Step: 2900, Average Loss: 0.000000
# Epoch: 17, Step: 3000, Average Loss: 0.000000
# Epoch: 17, Step: 3100, Average Loss: 0.000000
# Epoch: 17, Step: 3200, Average Loss: 0.000000
# Epoch: 17, Step: 3300, Average Loss: 0.000000
# Epoch: 18, Step: 100, Average Loss: 0.000000
# Epoch: 18, Step: 200, Average Loss: 0.000000
# Epoch: 18, Step: 300, Average Loss: 0.000000
# Epoch: 18, Step: 400, Average Loss: 0.000000
# Epoch: 18, Step: 500, Average Loss: 0.000000
# Epoch: 18, Step: 600, Average Loss: 0.000000
# Epoch: 18, Step: 700, Average Loss: 0.000000
# Epoch: 18, Step: 800, Average Loss: 0.000003
# Epoch: 18, Step: 900, Average Loss: 0.000000
# Epoch: 18, Step: 1000, Average Loss: 0.000000
# Epoch: 18, Step: 1100, Average Loss: 0.000000
# Epoch: 18, Step: 1200, Average Loss: 0.000000
# Epoch: 18, Step: 1300, Average Loss: 0.000000
# Epoch: 18, Step: 1400, Average Loss: 0.000000
# Epoch: 18, Step: 1500, Average Loss: 0.000000
# Epoch: 18, Step: 1600, Average Loss: 0.000000
# Epoch: 18, Step: 1700, Average Loss: 0.000017
# Epoch: 18, Step: 1800, Average Loss: 0.000000
# Epoch: 18, Step: 1900, Average Loss: 0.000000
# Epoch: 18, Step: 2000, Average Loss: 0.000000
# Epoch: 18, Step: 2100, Average Loss: 0.000000
# Epoch: 18, Step: 2200, Average Loss: 0.000002
# Epoch: 18, Step: 2300, Average Loss: 0.000003
# Epoch: 18, Step: 2400, Average Loss: 0.000000
# Epoch: 18, Step: 2500, Average Loss: 0.000002
# Epoch: 18, Step: 2600, Average Loss: 0.000001
# Epoch: 18, Step: 2700, Average Loss: 0.000000
# Epoch: 18, Step: 2800, Average Loss: 0.000000
# Epoch: 18, Step: 2900, Average Loss: 0.000000
# Epoch: 18, Step: 3000, Average Loss: 0.000000
# Epoch: 18, Step: 3100, Average Loss: 0.000000
# Epoch: 18, Step: 3200, Average Loss: 0.000000
# Epoch: 18, Step: 3300, Average Loss: 0.000000
# Epoch: 19, Step: 100, Average Loss: 0.000000
# Epoch: 19, Step: 200, Average Loss: 0.000000
# Epoch: 19, Step: 300, Average Loss: 0.000000
# Epoch: 19, Step: 400, Average Loss: 0.000000
# Epoch: 19, Step: 500, Average Loss: 0.000000
# Epoch: 19, Step: 600, Average Loss: 0.000000
# Epoch: 19, Step: 700, Average Loss: 0.000000
# Epoch: 19, Step: 800, Average Loss: 0.000008
# Epoch: 19, Step: 900, Average Loss: 0.000000
# Epoch: 19, Step: 1000, Average Loss: 0.000002
# Epoch: 19, Step: 1100, Average Loss: 0.000000
# Epoch: 19, Step: 1200, Average Loss: 0.000000
# Epoch: 19, Step: 1300, Average Loss: 0.000000
# Epoch: 19, Step: 1400, Average Loss: 0.000000
# Epoch: 19, Step: 1500, Average Loss: 0.000001
# Epoch: 19, Step: 1600, Average Loss: 0.000007
# Epoch: 19, Step: 1700, Average Loss: 0.000000
# Epoch: 19, Step: 1800, Average Loss: 0.000000
# Epoch: 19, Step: 1900, Average Loss: 0.000000
# Epoch: 19, Step: 2000, Average Loss: 0.000000
# Epoch: 19, Step: 2100, Average Loss: 0.000000
# Epoch: 19, Step: 2200, Average Loss: 0.000000
# Epoch: 19, Step: 2300, Average Loss: 0.000000
# Epoch: 19, Step: 2400, Average Loss: 0.000004
# Epoch: 19, Step: 2500, Average Loss: 0.000000
# Epoch: 19, Step: 2600, Average Loss: 0.000000
# Epoch: 19, Step: 2700, Average Loss: 0.000003
# Epoch: 19, Step: 2800, Average Loss: 0.000002
# Epoch: 19, Step: 2900, Average Loss: 0.000000
# Epoch: 19, Step: 3000, Average Loss: 0.000000
# Epoch: 19, Step: 3100, Average Loss: 0.000009
# Epoch: 19, Step: 3200, Average Loss: 0.000002
# Epoch: 19, Step: 3300, Average Loss: 0.000007
# Epoch: 20, Step: 100, Average Loss: 0.000000
# Epoch: 20, Step: 200, Average Loss: 0.000000
# Epoch: 20, Step: 300, Average Loss: 0.000001
# Epoch: 20, Step: 400, Average Loss: 0.000000
# Epoch: 20, Step: 500, Average Loss: 0.000000
# Epoch: 20, Step: 600, Average Loss: 0.000000
# Epoch: 20, Step: 700, Average Loss: 0.000000
# Epoch: 20, Step: 800, Average Loss: 0.000001
# Epoch: 20, Step: 900, Average Loss: 0.000001
# Epoch: 20, Step: 1000, Average Loss: 0.000000
# Epoch: 20, Step: 1100, Average Loss: 0.000000
# Epoch: 20, Step: 1200, Average Loss: 0.000000
# Epoch: 20, Step: 1300, Average Loss: 0.000000
# Epoch: 20, Step: 1400, Average Loss: 0.000000
# Epoch: 20, Step: 1500, Average Loss: 0.000000
# Epoch: 20, Step: 1600, Average Loss: 0.000000
# Epoch: 20, Step: 1700, Average Loss: 0.000000
# Epoch: 20, Step: 1800, Average Loss: 0.000000
# Epoch: 20, Step: 1900, Average Loss: 0.000000
# Epoch: 20, Step: 2000, Average Loss: 0.000000
# Epoch: 20, Step: 2100, Average Loss: 0.000000
# Epoch: 20, Step: 2200, Average Loss: 0.000003
# Epoch: 20, Step: 2300, Average Loss: 0.000005
# Epoch: 20, Step: 2400, Average Loss: 0.000000
# Epoch: 20, Step: 2500, Average Loss: 0.000000
# Epoch: 20, Step: 2600, Average Loss: 0.000000
# Epoch: 20, Step: 2700, Average Loss: 0.000000
# Epoch: 20, Step: 2800, Average Loss: 0.000000
# Epoch: 20, Step: 2900, Average Loss: 0.000001
# Epoch: 20, Step: 3000, Average Loss: 0.000000
# Epoch: 20, Step: 3100, Average Loss: 0.000000
# Epoch: 20, Step: 3200, Average Loss: 0.000000
# Epoch: 20, Step: 3300, Average Loss: 0.000000
# Epoch: 20, Validation Loss: 0.001627
# Epoch: 21, Step: 100, Average Loss: 0.000000
# Epoch: 21, Step: 200, Average Loss: 0.000000
# Epoch: 21, Step: 300, Average Loss: 0.000000
# Epoch: 21, Step: 400, Average Loss: 0.000004
# Epoch: 21, Step: 500, Average Loss: 0.000000
# Epoch: 21, Step: 600, Average Loss: 0.000000
# Epoch: 21, Step: 700, Average Loss: 0.000003
# Epoch: 21, Step: 800, Average Loss: 0.000000
# Epoch: 21, Step: 900, Average Loss: 0.000006
# Epoch: 21, Step: 1000, Average Loss: 0.000000
# Epoch: 21, Step: 1100, Average Loss: 0.000000
# Epoch: 21, Step: 1200, Average Loss: 0.000001
# Epoch: 21, Step: 1300, Average Loss: 0.000000
# Epoch: 21, Step: 1400, Average Loss: 0.000000
# Epoch: 21, Step: 1500, Average Loss: 0.000000
# Epoch: 21, Step: 1600, Average Loss: 0.000000
# Epoch: 21, Step: 1700, Average Loss: 0.000000
# Epoch: 21, Step: 1800, Average Loss: 0.000000
# Epoch: 21, Step: 1900, Average Loss: 0.000000
# Epoch: 21, Step: 2000, Average Loss: 0.000000
# Epoch: 21, Step: 2100, Average Loss: 0.000000
# Epoch: 21, Step: 2200, Average Loss: 0.000000
# Epoch: 21, Step: 2300, Average Loss: 0.000000
# Epoch: 21, Step: 2400, Average Loss: 0.000000
# Epoch: 21, Step: 2500, Average Loss: 0.000000
# Epoch: 21, Step: 2600, Average Loss: 0.000000
# Epoch: 21, Step: 2700, Average Loss: 0.000000
# Epoch: 21, Step: 2800, Average Loss: 0.000000
# Epoch: 21, Step: 2900, Average Loss: 0.000000
# Epoch: 21, Step: 3000, Average Loss: 0.000000
# Epoch: 21, Step: 3100, Average Loss: 0.000023
# Epoch: 21, Step: 3200, Average Loss: 0.000000
# Epoch: 21, Step: 3300, Average Loss: 0.000000
# Epoch: 22, Step: 100, Average Loss: 0.000000
# Epoch: 22, Step: 200, Average Loss: 0.000000
# Epoch: 22, Step: 300, Average Loss: 0.000000
# Epoch: 22, Step: 400, Average Loss: 0.000000
# Epoch: 22, Step: 500, Average Loss: 0.000000
# Epoch: 22, Step: 600, Average Loss: 0.000003
# Epoch: 22, Step: 700, Average Loss: 0.000000
# Epoch: 22, Step: 800, Average Loss: 0.000002
# Epoch: 22, Step: 900, Average Loss: 0.000000
# Epoch: 22, Step: 1000, Average Loss: 0.000000
# Epoch: 22, Step: 1100, Average Loss: 0.000010
# Epoch: 22, Step: 1200, Average Loss: 0.000000
# Epoch: 22, Step: 1300, Average Loss: 0.000000
# Epoch: 22, Step: 1400, Average Loss: 0.000000
# Epoch: 22, Step: 1500, Average Loss: 0.000000
# Epoch: 22, Step: 1600, Average Loss: 0.000001
# Epoch: 22, Step: 1700, Average Loss: 0.000000
# Epoch: 22, Step: 1800, Average Loss: 0.000000
# Epoch: 22, Step: 1900, Average Loss: 0.000005
# Epoch: 22, Step: 2000, Average Loss: 0.000000
# Epoch: 22, Step: 2100, Average Loss: 0.000001
# Epoch: 22, Step: 2200, Average Loss: 0.000000
# Epoch: 22, Step: 2300, Average Loss: 0.000000
# Epoch: 22, Step: 2400, Average Loss: 0.000000
# Epoch: 22, Step: 2500, Average Loss: 0.000000
# Epoch: 22, Step: 2600, Average Loss: 0.000000
# Epoch: 22, Step: 2700, Average Loss: 0.000000
# Epoch: 22, Step: 2800, Average Loss: 0.000000
# Epoch: 22, Step: 2900, Average Loss: 0.000000
# Epoch: 22, Step: 3000, Average Loss: 0.000001
# Epoch: 22, Step: 3100, Average Loss: 0.000000
# Epoch: 22, Step: 3200, Average Loss: 0.000000
# Epoch: 22, Step: 3300, Average Loss: 0.000000
# Epoch: 23, Step: 100, Average Loss: 0.000000
# Epoch: 23, Step: 200, Average Loss: 0.000000
# Epoch: 23, Step: 300, Average Loss: 0.000000
# Epoch: 23, Step: 400, Average Loss: 0.000000
# Epoch: 23, Step: 500, Average Loss: 0.000007
# Epoch: 23, Step: 600, Average Loss: 0.000000
# Epoch: 23, Step: 700, Average Loss: 0.000000
# Epoch: 23, Step: 800, Average Loss: 0.000001
# Epoch: 23, Step: 900, Average Loss: 0.000000
# Epoch: 23, Step: 1000, Average Loss: 0.000000
# Epoch: 23, Step: 1100, Average Loss: 0.000000
# Epoch: 23, Step: 1200, Average Loss: 0.000000
# Epoch: 23, Step: 1300, Average Loss: 0.000000
# Epoch: 23, Step: 1400, Average Loss: 0.000000
# Epoch: 23, Step: 1500, Average Loss: 0.000000
# Epoch: 23, Step: 1600, Average Loss: 0.000000
# Epoch: 23, Step: 1700, Average Loss: 0.000000
# Epoch: 23, Step: 1800, Average Loss: 0.000000
# Epoch: 23, Step: 1900, Average Loss: 0.000000
# Epoch: 23, Step: 2000, Average Loss: 0.000000
# Epoch: 23, Step: 2100, Average Loss: 0.000000
# Epoch: 23, Step: 2200, Average Loss: 0.000000
# Epoch: 23, Step: 2300, Average Loss: 0.000000
# Epoch: 23, Step: 2400, Average Loss: 0.000000
# Epoch: 23, Step: 2500, Average Loss: 0.000000
# Epoch: 23, Step: 2600, Average Loss: 0.000000
# Epoch: 23, Step: 2700, Average Loss: 0.000000
# Epoch: 23, Step: 2800, Average Loss: 0.000001
# Epoch: 23, Step: 2900, Average Loss: 0.000000
# Epoch: 23, Step: 3000, Average Loss: 0.000000
# Epoch: 23, Step: 3100, Average Loss: 0.000000
# Epoch: 23, Step: 3200, Average Loss: 0.000000
# Epoch: 23, Step: 3300, Average Loss: 0.000000
# Epoch: 24, Step: 100, Average Loss: 0.000000
# Epoch: 24, Step: 200, Average Loss: 0.000000
# Epoch: 24, Step: 300, Average Loss: 0.000003
# Epoch: 24, Step: 400, Average Loss: 0.000002
# Epoch: 24, Step: 500, Average Loss: 0.000000
# Epoch: 24, Step: 600, Average Loss: 0.000000
# Epoch: 24, Step: 700, Average Loss: 0.000000
# Epoch: 24, Step: 800, Average Loss: 0.000000
# Epoch: 24, Step: 900, Average Loss: 0.000000
# Epoch: 24, Step: 1000, Average Loss: 0.000000
# Epoch: 24, Step: 1100, Average Loss: 0.000000
# Epoch: 24, Step: 1200, Average Loss: 0.000001
# Epoch: 24, Step: 1300, Average Loss: 0.000000
# Epoch: 24, Step: 1400, Average Loss: 0.000001
# Epoch: 24, Step: 1500, Average Loss: 0.000000
# Epoch: 24, Step: 1600, Average Loss: 0.000000
# Epoch: 24, Step: 1700, Average Loss: 0.000001
# Epoch: 24, Step: 1800, Average Loss: 0.000006
# Epoch: 24, Step: 1900, Average Loss: 0.000000
# Epoch: 24, Step: 2000, Average Loss: 0.000002
# Epoch: 24, Step: 2100, Average Loss: 0.000000
# Epoch: 24, Step: 2200, Average Loss: 0.000000
# Epoch: 24, Step: 2300, Average Loss: 0.000000
# Epoch: 24, Step: 2400, Average Loss: 0.000000
# Epoch: 24, Step: 2500, Average Loss: 0.000000
# Epoch: 24, Step: 2600, Average Loss: 0.000000
# Epoch: 24, Step: 2700, Average Loss: 0.000000
# Epoch: 24, Step: 2800, Average Loss: 0.000000
# Epoch: 24, Step: 2900, Average Loss: 0.000000
# Epoch: 24, Step: 3000, Average Loss: 0.000001
# Epoch: 24, Step: 3100, Average Loss: 0.000000
# Epoch: 24, Step: 3200, Average Loss: 0.000000
# Epoch: 24, Step: 3300, Average Loss: 0.000000
# Epoch: 25, Step: 100, Average Loss: 0.000000
# Epoch: 25, Step: 200, Average Loss: 0.000000
# Epoch: 25, Step: 300, Average Loss: 0.000000
# Epoch: 25, Step: 400, Average Loss: 0.000000
# Epoch: 25, Step: 500, Average Loss: 0.000013
# Epoch: 25, Step: 600, Average Loss: 0.000000
# Epoch: 25, Step: 700, Average Loss: 0.000000
# Epoch: 25, Step: 800, Average Loss: 0.000000
# Epoch: 25, Step: 900, Average Loss: 0.000000
# Epoch: 25, Step: 1000, Average Loss: 0.000000
# Epoch: 25, Step: 1100, Average Loss: 0.000000
# Epoch: 25, Step: 1200, Average Loss: 0.000000
# Epoch: 25, Step: 1300, Average Loss: 0.000000
# Epoch: 25, Step: 1400, Average Loss: 0.000000
# Epoch: 25, Step: 1500, Average Loss: 0.000000
# Epoch: 25, Step: 1600, Average Loss: 0.000000
# Epoch: 25, Step: 1700, Average Loss: 0.000000
# Epoch: 25, Step: 1800, Average Loss: 0.000000
# Epoch: 25, Step: 1900, Average Loss: 0.000004
# Epoch: 25, Step: 2000, Average Loss: 0.000000
# Epoch: 25, Step: 2100, Average Loss: 0.000002
# Epoch: 25, Step: 2200, Average Loss: 0.000000
# Epoch: 25, Step: 2300, Average Loss: 0.000000
# Epoch: 25, Step: 2400, Average Loss: 0.000000
# Epoch: 25, Step: 2500, Average Loss: 0.000000
# Epoch: 25, Step: 2600, Average Loss: 0.000000
# Epoch: 25, Step: 2700, Average Loss: 0.000000
# Epoch: 25, Step: 2800, Average Loss: 0.000000
# Epoch: 25, Step: 2900, Average Loss: 0.000014
# Epoch: 25, Step: 3000, Average Loss: 0.000000
# Epoch: 25, Step: 3100, Average Loss: 0.000000
# Epoch: 25, Step: 3200, Average Loss: 0.000000
# Epoch: 25, Step: 3300, Average Loss: 0.000000
# Epoch: 25, Validation Loss: 0.000631
# Epoch: 26, Step: 100, Average Loss: 0.000000
# Epoch: 26, Step: 200, Average Loss: 0.000000
# Epoch: 26, Step: 300, Average Loss: 0.000000
# Epoch: 26, Step: 400, Average Loss: 0.000000
# Epoch: 26, Step: 500, Average Loss: 0.000009
# Epoch: 26, Step: 600, Average Loss: 0.000000
# Epoch: 26, Step: 700, Average Loss: 0.000002
# Epoch: 26, Step: 800, Average Loss: 0.000000
# Epoch: 26, Step: 900, Average Loss: 0.000001
# Epoch: 26, Step: 1000, Average Loss: 0.000018
# Epoch: 26, Step: 1100, Average Loss: 0.000000
# Epoch: 26, Step: 1200, Average Loss: 0.000000
# Epoch: 26, Step: 1300, Average Loss: 0.000000
# Epoch: 26, Step: 1400, Average Loss: 0.000010
# Epoch: 26, Step: 1500, Average Loss: 0.000000
# Epoch: 26, Step: 1600, Average Loss: 0.000000
# Epoch: 26, Step: 1700, Average Loss: 0.000000
# Epoch: 26, Step: 1800, Average Loss: 0.000000
# Epoch: 26, Step: 1900, Average Loss: 0.000000
# Epoch: 26, Step: 2000, Average Loss: 0.000001
# Epoch: 26, Step: 2100, Average Loss: 0.000000
# Epoch: 26, Step: 2200, Average Loss: 0.000000
# Epoch: 26, Step: 2300, Average Loss: 0.000000
# Epoch: 26, Step: 2400, Average Loss: 0.000000
# Epoch: 26, Step: 2500, Average Loss: 0.000000
# Epoch: 26, Step: 2600, Average Loss: 0.000000
# Epoch: 26, Step: 2700, Average Loss: 0.000002
# Epoch: 26, Step: 2800, Average Loss: 0.000000
# Epoch: 26, Step: 2900, Average Loss: 0.000000
# Epoch: 26, Step: 3000, Average Loss: 0.000000
# Epoch: 26, Step: 3100, Average Loss: 0.000000
# Epoch: 26, Step: 3200, Average Loss: 0.000070
# Epoch: 26, Step: 3300, Average Loss: 0.000000
# Epoch: 27, Step: 100, Average Loss: 0.000000
# Epoch: 27, Step: 200, Average Loss: 0.000002
# Epoch: 27, Step: 300, Average Loss: 0.000000
# Epoch: 27, Step: 400, Average Loss: 0.000000
# Epoch: 27, Step: 500, Average Loss: 0.000000
# Epoch: 27, Step: 600, Average Loss: 0.000000
# Epoch: 27, Step: 700, Average Loss: 0.000000
# Epoch: 27, Step: 800, Average Loss: 0.000000
# Epoch: 27, Step: 900, Average Loss: 0.000000
# Epoch: 27, Step: 1000, Average Loss: 0.000002
# Epoch: 27, Step: 1100, Average Loss: 0.000000
# Epoch: 27, Step: 1200, Average Loss: 0.000000
# Epoch: 27, Step: 1300, Average Loss: 0.000001
# Epoch: 27, Step: 1400, Average Loss: 0.000000
# Epoch: 27, Step: 1500, Average Loss: 0.000000
# Epoch: 27, Step: 1600, Average Loss: 0.000000
# Epoch: 27, Step: 1700, Average Loss: 0.000001
# Epoch: 27, Step: 1800, Average Loss: 0.000000
# Epoch: 27, Step: 1900, Average Loss: 0.000000
# Epoch: 27, Step: 2000, Average Loss: 0.000000
# Epoch: 27, Step: 2100, Average Loss: 0.000000
# Epoch: 27, Step: 2200, Average Loss: 0.000000
# Epoch: 27, Step: 2300, Average Loss: 0.000000
# Epoch: 27, Step: 2400, Average Loss: 0.000000
# Epoch: 27, Step: 2500, Average Loss: 0.000002
# Epoch: 27, Step: 2600, Average Loss: 0.000000
# Epoch: 27, Step: 2700, Average Loss: 0.000000
# Epoch: 27, Step: 2800, Average Loss: 0.000000
# Epoch: 27, Step: 2900, Average Loss: 0.000000
# Epoch: 27, Step: 3000, Average Loss: 0.000002
# Epoch: 27, Step: 3100, Average Loss: 0.000117
# Epoch: 27, Step: 3200, Average Loss: 0.000000
# Epoch: 27, Step: 3300, Average Loss: 0.000001
# Epoch: 28, Step: 100, Average Loss: 0.000000
# Epoch: 28, Step: 200, Average Loss: 0.000002
# Epoch: 28, Step: 300, Average Loss: 0.000001
# Epoch: 28, Step: 400, Average Loss: 0.000000
# Epoch: 28, Step: 500, Average Loss: 0.000000
# Epoch: 28, Step: 600, Average Loss: 0.000000
# Epoch: 28, Step: 700, Average Loss: 0.000003
# Epoch: 28, Step: 800, Average Loss: 0.000000
# Epoch: 28, Step: 900, Average Loss: 0.000000
# Epoch: 28, Step: 1000, Average Loss: 0.000003
# Epoch: 28, Step: 1100, Average Loss: 0.000000
# Epoch: 28, Step: 1200, Average Loss: 0.000000
# Epoch: 28, Step: 1300, Average Loss: 0.000005
# Epoch: 28, Step: 1400, Average Loss: 0.000000
# Epoch: 28, Step: 1500, Average Loss: 0.000000
# Epoch: 28, Step: 1600, Average Loss: 0.000000
# Epoch: 28, Step: 1700, Average Loss: 0.000000
# Epoch: 28, Step: 1800, Average Loss: 0.000000
# Epoch: 28, Step: 1900, Average Loss: 0.000000
# Epoch: 28, Step: 2000, Average Loss: 0.000001
# Epoch: 28, Step: 2100, Average Loss: 0.000000
# Epoch: 28, Step: 2200, Average Loss: 0.000000
# Epoch: 28, Step: 2300, Average Loss: 0.000000
# Epoch: 28, Step: 2400, Average Loss: 0.000000
# Epoch: 28, Step: 2500, Average Loss: 0.000000
# Epoch: 28, Step: 2600, Average Loss: 0.000000
# Epoch: 28, Step: 2700, Average Loss: 0.000000
# Epoch: 28, Step: 2800, Average Loss: 0.000000
# Epoch: 28, Step: 2900, Average Loss: 0.000000
# Epoch: 28, Step: 3000, Average Loss: 0.000000
# Epoch: 28, Step: 3100, Average Loss: 0.000000
# Epoch: 28, Step: 3200, Average Loss: 0.000005
# Epoch: 28, Step: 3300, Average Loss: 0.000000
# Epoch: 29, Step: 100, Average Loss: 0.000000
# Epoch: 29, Step: 200, Average Loss: 0.000000
# Epoch: 29, Step: 300, Average Loss: 0.000000
# Epoch: 29, Step: 400, Average Loss: 0.000001
# Epoch: 29, Step: 500, Average Loss: 0.000002
# Epoch: 29, Step: 600, Average Loss: 0.000000
# Epoch: 29, Step: 700, Average Loss: 0.000000
# Epoch: 29, Step: 800, Average Loss: 0.000000
# Epoch: 29, Step: 900, Average Loss: 0.000000
# Epoch: 29, Step: 1000, Average Loss: 0.000001
# Epoch: 29, Step: 1100, Average Loss: 0.000000
# Epoch: 29, Step: 1200, Average Loss: 0.000000
# Epoch: 29, Step: 1300, Average Loss: 0.000001
# Epoch: 29, Step: 1400, Average Loss: 0.000004
# Epoch: 29, Step: 1500, Average Loss: 0.000036
# Epoch: 29, Step: 1600, Average Loss: 0.000000
# Epoch: 29, Step: 1700, Average Loss: 0.000000
# Epoch: 29, Step: 1800, Average Loss: 0.000000
# Epoch: 29, Step: 1900, Average Loss: 0.000000
# Epoch: 29, Step: 2000, Average Loss: 0.000000
# Epoch: 29, Step: 2100, Average Loss: 0.000000
# Epoch: 29, Step: 2200, Average Loss: 0.000000
# Epoch: 29, Step: 2300, Average Loss: 0.000001
# Epoch: 29, Step: 2400, Average Loss: 0.000016
# Epoch: 29, Step: 2500, Average Loss: 0.000000
# Epoch: 29, Step: 2600, Average Loss: 0.000000
# Epoch: 29, Step: 2700, Average Loss: 0.000000
# Epoch: 29, Step: 2800, Average Loss: 0.000000
# Epoch: 29, Step: 2900, Average Loss: 0.000000
# Epoch: 29, Step: 3000, Average Loss: 0.000000
# Epoch: 29, Step: 3100, Average Loss: 0.000001
# Epoch: 29, Step: 3200, Average Loss: 0.000000
# Epoch: 29, Step: 3300, Average Loss: 0.000001
# Epoch: 30, Step: 100, Average Loss: 0.000000
# Epoch: 30, Step: 200, Average Loss: 0.000000
# Epoch: 30, Step: 300, Average Loss: 0.000000
# Epoch: 30, Step: 400, Average Loss: 0.000002
# Epoch: 30, Step: 500, Average Loss: 0.000000
# Epoch: 30, Step: 600, Average Loss: 0.000000
# Epoch: 30, Step: 700, Average Loss: 0.000001
# Epoch: 30, Step: 800, Average Loss: 0.000000
# Epoch: 30, Step: 900, Average Loss: 0.000000
# Epoch: 30, Step: 1000, Average Loss: 0.000000
# Epoch: 30, Step: 1100, Average Loss: 0.000000
# Epoch: 30, Step: 1200, Average Loss: 0.000003
# Epoch: 30, Step: 1300, Average Loss: 0.000000
# Epoch: 30, Step: 1400, Average Loss: 0.000000
# Epoch: 30, Step: 1500, Average Loss: 0.000037
# Epoch: 30, Step: 1600, Average Loss: 0.000000
# Epoch: 30, Step: 1700, Average Loss: 0.000000
# Epoch: 30, Step: 1800, Average Loss: 0.000000
# Epoch: 30, Step: 1900, Average Loss: 0.000000
# Epoch: 30, Step: 2000, Average Loss: 0.000000
# Epoch: 30, Step: 2100, Average Loss: 0.000000
# Epoch: 30, Step: 2200, Average Loss: 0.000000
# Epoch: 30, Step: 2300, Average Loss: 0.000000
# Epoch: 30, Step: 2400, Average Loss: 0.000001
# Epoch: 30, Step: 2500, Average Loss: 0.000000
# Epoch: 30, Step: 2600, Average Loss: 0.000000
# Epoch: 30, Step: 2700, Average Loss: 0.000000
# Epoch: 30, Step: 2800, Average Loss: 0.000000
# Epoch: 30, Step: 2900, Average Loss: 0.000001
# Epoch: 30, Step: 3000, Average Loss: 0.000000
# Epoch: 30, Step: 3100, Average Loss: 0.000000
# Epoch: 30, Step: 3200, Average Loss: 0.000000
# Epoch: 30, Step: 3300, Average Loss: 0.000003
# Epoch: 30, Validation Loss: 0.000363
# Epoch: 31, Step: 100, Average Loss: 0.000001
# Epoch: 31, Step: 200, Average Loss: 0.000000
# Epoch: 31, Step: 300, Average Loss: 0.000001
# Epoch: 31, Step: 400, Average Loss: 0.000000
# Epoch: 31, Step: 500, Average Loss: 0.000000
# Epoch: 31, Step: 600, Average Loss: 0.000001
# Epoch: 31, Step: 700, Average Loss: 0.000000
# Epoch: 31, Step: 800, Average Loss: 0.000005
# Epoch: 31, Step: 900, Average Loss: 0.000001
# Epoch: 31, Step: 1000, Average Loss: 0.000000
# Epoch: 31, Step: 1100, Average Loss: 0.000000
# Epoch: 31, Step: 1200, Average Loss: 0.000000
# Epoch: 31, Step: 1300, Average Loss: 0.000000
# Epoch: 31, Step: 1400, Average Loss: 0.000000
# Epoch: 31, Step: 1500, Average Loss: 0.000004
# Epoch: 31, Step: 1600, Average Loss: 0.000001
# ...
# Epoch: 39, Step: 1700, Average Loss: 0.000000
# Epoch: 39, Step: 1800, Average Loss: 0.000000
# Epoch: 39, Step: 1900, Average Loss: 0.000000
# Epoch: 39, Step: 2000, Average Loss: 0.000000
# Epoch: 39, Step: 2100, Average Loss: 0.000001
# Epoch: 39, Step: 2200, Average Loss: 0.000000
# Epoch: 39, Step: 2300, Average Loss: 0.000000
# Epoch: 39, Step: 2400, Average Loss: 0.000007
# Epoch: 39, Step: 2500, Average Loss: 0.000000
# Epoch: 39, Step: 2600, Average Loss: 0.000084
# Epoch: 39, Step: 2700, Average Loss: 0.000000
# Epoch: 39, Step: 2800, Average Loss: 0.000000
# Epoch: 39, Step: 2900, Average Loss: 0.000000
# Epoch: 39, Step: 3000, Average Loss: 0.000000
# Epoch: 39, Step: 3100, Average Loss: 0.000000
# Epoch: 39, Step: 3200, Average Loss: 0.000001
# Epoch: 39, Step: 3300, Average Loss: 0.000000
# Epoch: 40, Step: 100, Average Loss: 0.000000
# Epoch: 40, Step: 200, Average Loss: 0.000002
# Epoch: 40, Step: 300, Average Loss: 0.000000
# Epoch: 40, Step: 400, Average Loss: 0.000000
# Epoch: 40, Step: 500, Average Loss: 0.000000
# Epoch: 40, Step: 600, Average Loss: 0.000000
# Epoch: 40, Step: 700, Average Loss: 0.000000
# Epoch: 40, Step: 800, Average Loss: 0.000000
# Epoch: 40, Step: 900, Average Loss: 0.000000
# Epoch: 40, Step: 1000, Average Loss: 0.000000
# Epoch: 40, Step: 1100, Average Loss: 0.000000
# Epoch: 40, Step: 1200, Average Loss: 0.000000
# Epoch: 40, Step: 1300, Average Loss: 0.000000
# Epoch: 40, Step: 1400, Average Loss: 0.000000
# Epoch: 40, Step: 1500, Average Loss: 0.000000
# Epoch: 40, Step: 1600, Average Loss: 0.000000
# Epoch: 40, Step: 1700, Average Loss: 0.000000
# Epoch: 40, Step: 1800, Average Loss: 0.000000
# Epoch: 40, Step: 1900, Average Loss: 0.000000
# Epoch: 40, Step: 2000, Average Loss: 0.000000
# Epoch: 40, Step: 2100, Average Loss: 0.000000
# Epoch: 40, Step: 2200, Average Loss: 0.000000
# Epoch: 40, Step: 2300, Average Loss: 0.000000
# Epoch: 40, Step: 2400, Average Loss: 0.000000
# Epoch: 40, Step: 2500, Average Loss: 0.000001
# Epoch: 40, Step: 2600, Average Loss: 0.000000
# Epoch: 40, Step: 2700, Average Loss: 0.000000
# Epoch: 40, Step: 2800, Average Loss: 0.000000
# Epoch: 40, Step: 2900, Average Loss: 0.000000
# Epoch: 40, Step: 3000, Average Loss: 0.000006
# Epoch: 40, Step: 3100, Average Loss: 0.000000
# Epoch: 40, Step: 3200, Average Loss: 0.000000
# Epoch: 40, Step: 3300, Average Loss: 0.000003
# Epoch: 40, Validation Loss: 0.000330
# Epoch: 41, Step: 100, Average Loss: 0.000001
# Epoch: 41, Step: 200, Average Loss: 0.000000
# Epoch: 41, Step: 300, Average Loss: 0.000000
# Epoch: 41, Step: 400, Average Loss: 0.000000
# Epoch: 41, Step: 500, Average Loss: 0.000000
# Epoch: 41, Step: 600, Average Loss: 0.000000
# Epoch: 41, Step: 700, Average Loss: 0.000000
# Epoch: 41, Step: 800, Average Loss: 0.000000
# Epoch: 41, Step: 900, Average Loss: 0.000000
# Epoch: 41, Step: 1000, Average Loss: 0.000000
# Epoch: 41, Step: 1100, Average Loss: 0.000000
# Epoch: 41, Step: 1200, Average Loss: 0.000000
# Epoch: 41, Step: 1300, Average Loss: 0.000000
# Epoch: 41, Step: 1400, Average Loss: 0.000001
# Epoch: 41, Step: 1500, Average Loss: 0.000000
# Epoch: 41, Step: 1600, Average Loss: 0.000000
# Epoch: 41, Step: 1700, Average Loss: 0.000000
# Epoch: 41, Step: 1800, Average Loss: 0.000000
# Epoch: 41, Step: 1900, Average Loss: 0.000000
# Epoch: 41, Step: 2000, Average Loss: 0.000001
# Epoch: 41, Step: 2100, Average Loss: 0.000000
# Epoch: 41, Step: 2200, Average Loss: 0.000000
# Epoch: 41, Step: 2300, Average Loss: 0.000000
# Epoch: 41, Step: 2400, Average Loss: 0.000001
# Epoch: 41, Step: 2500, Average Loss: 0.000003
# Epoch: 41, Step: 2600, Average Loss: 0.000000
# Epoch: 41, Step: 2700, Average Loss: 0.000000
# Epoch: 41, Step: 2800, Average Loss: 0.000000
# Epoch: 41, Step: 2900, Average Loss: 0.000000
# Epoch: 41, Step: 3000, Average Loss: 0.000000
# Epoch: 41, Step: 3100, Average Loss: 0.000000
# Epoch: 41, Step: 3200, Average Loss: 0.000001
# Epoch: 41, Step: 3300, Average Loss: 0.000000
# Epoch: 42, Step: 100, Average Loss: 0.000000
# Epoch: 42, Step: 200, Average Loss: 0.000000
# Epoch: 42, Step: 300, Average Loss: 0.000000
# Epoch: 42, Step: 400, Average Loss: 0.000000
# Epoch: 42, Step: 500, Average Loss: 0.000000
# Epoch: 42, Step: 600, Average Loss: 0.000000
# Epoch: 42, Step: 700, Average Loss: 0.000002
# Epoch: 42, Step: 800, Average Loss: 0.000000
# Epoch: 42, Step: 900, Average Loss: 0.000003
# Epoch: 42, Step: 1000, Average Loss: 0.000000
# Epoch: 42, Step: 1100, Average Loss: 0.000000
# Epoch: 42, Step: 1200, Average Loss: 0.000000
# Epoch: 42, Step: 1300, Average Loss: 0.000007
# Epoch: 42, Step: 1400, Average Loss: 0.000000
# Epoch: 42, Step: 1500, Average Loss: 0.000001
# Epoch: 42, Step: 1600, Average Loss: 0.000000
# Epoch: 42, Step: 1700, Average Loss: 0.000200
# Epoch: 42, Step: 1800, Average Loss: 0.000000
# Epoch: 42, Step: 1900, Average Loss: 0.000000
# Epoch: 42, Step: 2000, Average Loss: 0.000001
# Epoch: 42, Step: 2100, Average Loss: 0.000001
# Epoch: 42, Step: 2200, Average Loss: 0.000000
# Epoch: 42, Step: 2300, Average Loss: 0.000000
# Epoch: 42, Step: 2400, Average Loss: 0.000000
# Epoch: 42, Step: 2500, Average Loss: 0.000000
# Epoch: 42, Step: 2600, Average Loss: 0.000000
# Epoch: 42, Step: 2700, Average Loss: 0.000000
# Epoch: 42, Step: 2800, Average Loss: 0.000000
# Epoch: 42, Step: 2900, Average Loss: 0.000000
# Epoch: 42, Step: 3000, Average Loss: 0.000000
# Epoch: 42, Step: 3100, Average Loss: 0.000000
# Epoch: 42, Step: 3200, Average Loss: 0.000000
# Epoch: 42, Step: 3300, Average Loss: 0.000000
# Epoch: 43, Step: 100, Average Loss: 0.000003
# Epoch: 43, Step: 200, Average Loss: 0.000000
# Epoch: 43, Step: 300, Average Loss: 0.000000
# Epoch: 43, Step: 400, Average Loss: 0.000000
# Epoch: 43, Step: 500, Average Loss: 0.000000
# Epoch: 43, Step: 600, Average Loss: 0.000000
# Epoch: 43, Step: 700, Average Loss: 0.000000
# Epoch: 43, Step: 800, Average Loss: 0.000000
# Epoch: 43, Step: 900, Average Loss: 0.000002
# Epoch: 43, Step: 1000, Average Loss: 0.000000
# Epoch: 43, Step: 1100, Average Loss: 0.000000
# Epoch: 43, Step: 1200, Average Loss: 0.000000
# Epoch: 43, Step: 1300, Average Loss: 0.000001
# Epoch: 43, Step: 1400, Average Loss: 0.000000
# Epoch: 43, Step: 1500, Average Loss: 0.000000
# Epoch: 43, Step: 1600, Average Loss: 0.000002
# Epoch: 43, Step: 1700, Average Loss: 0.000009
# Epoch: 43, Step: 1800, Average Loss: 0.000002
# Epoch: 43, Step: 1900, Average Loss: 0.000000
# Epoch: 43, Step: 2000, Average Loss: 0.000000
# Epoch: 43, Step: 2100, Average Loss: 0.000000
# Epoch: 43, Step: 2200, Average Loss: 0.000004
# Epoch: 43, Step: 2300, Average Loss: 0.000000
# Epoch: 43, Step: 2400, Average Loss: 0.000002
# Epoch: 43, Step: 2500, Average Loss: 0.000008
# Epoch: 43, Step: 2600, Average Loss: 0.000000
# Epoch: 43, Step: 2700, Average Loss: 0.000000
# Epoch: 43, Step: 2800, Average Loss: 0.000000
# Epoch: 43, Step: 2900, Average Loss: 0.000000
# Epoch: 43, Step: 3000, Average Loss: 0.000000
# Epoch: 43, Step: 3100, Average Loss: 0.000000
# Epoch: 43, Step: 3200, Average Loss: 0.000000
# Epoch: 43, Step: 3300, Average Loss: 0.000001
# Epoch: 44, Step: 100, Average Loss: 0.000000
# Epoch: 44, Step: 200, Average Loss: 0.000000
# Epoch: 44, Step: 300, Average Loss: 0.000000
# Epoch: 44, Step: 400, Average Loss: 0.000000
# Epoch: 44, Step: 500, Average Loss: 0.000000
# Epoch: 44, Step: 600, Average Loss: 0.000001
# Epoch: 44, Step: 700, Average Loss: 0.000000
# Epoch: 44, Step: 800, Average Loss: 0.000000
# Epoch: 44, Step: 900, Average Loss: 0.000001
# Epoch: 44, Step: 1000, Average Loss: 0.000000
# Epoch: 44, Step: 1100, Average Loss: 0.000100
# Epoch: 44, Step: 1200, Average Loss: 0.000001
# Epoch: 44, Step: 1300, Average Loss: 0.000000
# Epoch: 44, Step: 1400, Average Loss: 0.000002
# Epoch: 44, Step: 1500, Average Loss: 0.000004
# Epoch: 44, Step: 1600, Average Loss: 0.000000
# Epoch: 44, Step: 1700, Average Loss: 0.000000
# Epoch: 44, Step: 1800, Average Loss: 0.000000
# Epoch: 44, Step: 1900, Average Loss: 0.000000
# Epoch: 44, Step: 2000, Average Loss: 0.000000
# Epoch: 44, Step: 2100, Average Loss: 0.000000
# Epoch: 44, Step: 2200, Average Loss: 0.000000
# Epoch: 44, Step: 2300, Average Loss: 0.000000
# Epoch: 44, Step: 2400, Average Loss: 0.000002
# Epoch: 44, Step: 2500, Average Loss: 0.000000
# Epoch: 44, Step: 2600, Average Loss: 0.000000
# Epoch: 44, Step: 2700, Average Loss: 0.000000
# Epoch: 44, Step: 2800, Average Loss: 0.000000
# Epoch: 44, Step: 2900, Average Loss: 0.000000
# Epoch: 44, Step: 3000, Average Loss: 0.000000
# Epoch: 44, Step: 3100, Average Loss: 0.000001
# Epoch: 44, Step: 3200, Average Loss: 0.000000
# Epoch: 44, Step: 3300, Average Loss: 0.000000
# Epoch: 45, Step: 100, Average Loss: 0.000001
# Epoch: 45, Step: 200, Average Loss: 0.000000
# Epoch: 45, Step: 300, Average Loss: 0.000000
# Epoch: 45, Step: 400, Average Loss: 0.000000
# Epoch: 45, Step: 500, Average Loss: 0.000000
# Epoch: 45, Step: 600, Average Loss: 0.000000
# Epoch: 45, Step: 700, Average Loss: 0.000001
# Epoch: 45, Step: 800, Average Loss: 0.000002
# Epoch: 45, Step: 900, Average Loss: 0.000000
# Epoch: 45, Step: 1000, Average Loss: 0.000000
# Epoch: 45, Step: 1100, Average Loss: 0.000000
# Epoch: 45, Step: 1200, Average Loss: 0.000000
# Epoch: 45, Step: 1300, Average Loss: 0.000000
# Epoch: 45, Step: 1400, Average Loss: 0.000000
# Epoch: 45, Step: 1500, Average Loss: 0.000000
# Epoch: 45, Step: 1600, Average Loss: 0.000000
# Epoch: 45, Step: 1700, Average Loss: 0.000000
# Epoch: 45, Step: 1800, Average Loss: 0.000000
# Epoch: 45, Step: 1900, Average Loss: 0.000000
# Epoch: 45, Step: 2000, Average Loss: 0.000000
# Epoch: 45, Step: 2100, Average Loss: 0.000000
# Epoch: 45, Step: 2200, Average Loss: 0.000000
# Epoch: 45, Step: 2300, Average Loss: 0.000002
# Epoch: 45, Step: 2400, Average Loss: 0.000000
# Epoch: 45, Step: 2500, Average Loss: 0.000001
# Epoch: 45, Step: 2600, Average Loss: 0.000000
# Epoch: 45, Step: 2700, Average Loss: 0.000000
# Epoch: 45, Step: 2800, Average Loss: 0.000000
# Epoch: 45, Step: 2900, Average Loss: 0.000000
# Epoch: 45, Step: 3000, Average Loss: 0.000000
# Epoch: 45, Step: 3100, Average Loss: 0.000000
# Epoch: 45, Step: 3200, Average Loss: 0.000000
# Epoch: 45, Step: 3300, Average Loss: 0.000002
# Epoch: 45, Validation Loss: 0.000366
# Epoch: 46, Step: 100, Average Loss: 0.000000
# Epoch: 46, Step: 200, Average Loss: 0.000000
# Epoch: 46, Step: 300, Average Loss: 0.000001
# Epoch: 46, Step: 400, Average Loss: 0.000002
# Epoch: 46, Step: 500, Average Loss: 0.000000
# Epoch: 46, Step: 600, Average Loss: 0.000000
# Epoch: 46, Step: 700, Average Loss: 0.000000
# Epoch: 46, Step: 800, Average Loss: 0.000000
# Epoch: 46, Step: 900, Average Loss: 0.000000
# Epoch: 46, Step: 1000, Average Loss: 0.000000
# Epoch: 46, Step: 1100, Average Loss: 0.000000
# Epoch: 46, Step: 1200, Average Loss: 0.000000
# Epoch: 46, Step: 1300, Average Loss: 0.000000
# Epoch: 46, Step: 1400, Average Loss: 0.000000
# Epoch: 46, Step: 1500, Average Loss: 0.000000
# Epoch: 46, Step: 1600, Average Loss: 0.000000
# Epoch: 46, Step: 1700, Average Loss: 0.000000
# Epoch: 46, Step: 1800, Average Loss: 0.000000
# Epoch: 46, Step: 1900, Average Loss: 0.000000
# Epoch: 46, Step: 2000, Average Loss: 0.000001
# Epoch: 46, Step: 2100, Average Loss: 0.000000
# Epoch: 46, Step: 2200, Average Loss: 0.000000
# Epoch: 46, Step: 2300, Average Loss: 0.000000
# Epoch: 46, Step: 2400, Average Loss: 0.000003
# Epoch: 46, Step: 2500, Average Loss: 0.000000
# Epoch: 46, Step: 2600, Average Loss: 0.000000
# Epoch: 46, Step: 2700, Average Loss: 0.000000
# Epoch: 46, Step: 2800, Average Loss: 0.000000
# Epoch: 46, Step: 2900, Average Loss: 0.000000
# Epoch: 46, Step: 3000, Average Loss: 0.000000
# Epoch: 46, Step: 3100, Average Loss: 0.000000
# Epoch: 46, Step: 3200, Average Loss: 0.000000
# Epoch: 46, Step: 3300, Average Loss: 0.000015
# Epoch: 47, Step: 100, Average Loss: 0.000000
# Epoch: 47, Step: 200, Average Loss: 0.000000
# Epoch: 47, Step: 300, Average Loss: 0.000000
# Epoch: 47, Step: 400, Average Loss: 0.000003
# Epoch: 47, Step: 500, Average Loss: 0.000000
# Epoch: 47, Step: 600, Average Loss: 0.000002
# Epoch: 47, Step: 700, Average Loss: 0.000001
# Epoch: 47, Step: 800, Average Loss: 0.000000
# Epoch: 47, Step: 900, Average Loss: 0.000001
# Epoch: 47, Step: 1000, Average Loss: 0.000000
# Epoch: 47, Step: 1100, Average Loss: 0.000000
# Epoch: 47, Step: 1200, Average Loss: 0.000001
# Epoch: 47, Step: 1300, Average Loss: 0.000000
# Epoch: 47, Step: 1400, Average Loss: 0.000000
# Epoch: 47, Step: 1500, Average Loss: 0.000000
# Epoch: 47, Step: 1600, Average Loss: 0.000000
# Epoch: 47, Step: 1700, Average Loss: 0.000000
# Epoch: 47, Step: 1800, Average Loss: 0.000000
# Epoch: 47, Step: 1900, Average Loss: 0.000004
# Epoch: 47, Step: 2000, Average Loss: 0.000000
# Epoch: 47, Step: 2100, Average Loss: 0.000000
# Epoch: 47, Step: 2200, Average Loss: 0.000000
# Epoch: 47, Step: 2300, Average Loss: 0.000000
# Epoch: 47, Step: 2400, Average Loss: 0.000000
# Epoch: 47, Step: 2500, Average Loss: 0.000000
# Epoch: 47, Step: 2600, Average Loss: 0.000000
# Epoch: 47, Step: 2700, Average Loss: 0.000000
# Epoch: 47, Step: 2800, Average Loss: 0.000014
# Epoch: 47, Step: 2900, Average Loss: 0.000001
# Epoch: 47, Step: 3000, Average Loss: 0.000000
# Epoch: 47, Step: 3100, Average Loss: 0.000000
# Epoch: 47, Step: 3200, Average Loss: 0.000001
# Epoch: 47, Step: 3300, Average Loss: 0.000005
# Epoch: 48, Step: 100, Average Loss: 0.000000
# Epoch: 48, Step: 200, Average Loss: 0.000000
# Epoch: 48, Step: 300, Average Loss: 0.000000
# Epoch: 48, Step: 400, Average Loss: 0.000000
# Epoch: 48, Step: 500, Average Loss: 0.000001
# Epoch: 48, Step: 600, Average Loss: 0.000000
# Epoch: 48, Step: 700, Average Loss: 0.000000
# Epoch: 48, Step: 800, Average Loss: 0.000000
# Epoch: 48, Step: 900, Average Loss: 0.000115
# Epoch: 48, Step: 1000, Average Loss: 0.000000
# Epoch: 48, Step: 1100, Average Loss: 0.000001
# Epoch: 48, Step: 1200, Average Loss: 0.000053
# Epoch: 48, Step: 1300, Average Loss: 0.000000
# Epoch: 48, Step: 1400, Average Loss: 0.000000
# Epoch: 48, Step: 1500, Average Loss: 0.000000
# Epoch: 48, Step: 1600, Average Loss: 0.000000
# Epoch: 48, Step: 1700, Average Loss: 0.000001
# Epoch: 48, Step: 1800, Average Loss: 0.000000
# Epoch: 48, Step: 1900, Average Loss: 0.000000
# Epoch: 48, Step: 2000, Average Loss: 0.000000
# Epoch: 48, Step: 2100, Average Loss: 0.000000
# Epoch: 48, Step: 2200, Average Loss: 0.000000
# Epoch: 48, Step: 2300, Average Loss: 0.000000
# Epoch: 48, Step: 2400, Average Loss: 0.000000
# Epoch: 48, Step: 2500, Average Loss: 0.000000
# Epoch: 48, Step: 2600, Average Loss: 0.000000
# Epoch: 48, Step: 2700, Average Loss: 0.000000
# Epoch: 48, Step: 2800, Average Loss: 0.000000
# Epoch: 48, Step: 2900, Average Loss: 0.000000
# Epoch: 48, Step: 3000, Average Loss: 0.000000
# Epoch: 48, Step: 3100, Average Loss: 0.000068
# Epoch: 48, Step: 3200, Average Loss: 0.000000
# Epoch: 48, Step: 3300, Average Loss: 0.000000
# Epoch: 49, Step: 100, Average Loss: 0.000000
# Epoch: 49, Step: 200, Average Loss: 0.000000
# Epoch: 49, Step: 300, Average Loss: 0.000000
# Epoch: 49, Step: 400, Average Loss: 0.000000
# Epoch: 49, Step: 500, Average Loss: 0.000000
# Epoch: 49, Step: 600, Average Loss: 0.000000
# Epoch: 49, Step: 700, Average Loss: 0.000000
# Epoch: 49, Step: 800, Average Loss: 0.000000
# Epoch: 49, Step: 900, Average Loss: 0.000001
# Epoch: 49, Step: 1000, Average Loss: 0.000000
# Epoch: 49, Step: 1100, Average Loss: 0.000000
# Epoch: 49, Step: 1200, Average Loss: 0.000000
# Epoch: 49, Step: 1300, Average Loss: 0.000001
# Epoch: 49, Step: 1400, Average Loss: 0.000000
# Epoch: 49, Step: 1500, Average Loss: 0.000024
# Epoch: 49, Step: 1600, Average Loss: 0.000000
# Epoch: 49, Step: 1700, Average Loss: 0.000000
# Epoch: 49, Step: 1800, Average Loss: 0.000010
# Epoch: 49, Step: 1900, Average Loss: 0.000000
# Epoch: 49, Step: 2000, Average Loss: 0.000000
# Epoch: 49, Step: 2100, Average Loss: 0.000000
# Epoch: 49, Step: 2200, Average Loss: 0.000000
# Epoch: 49, Step: 2300, Average Loss: 0.000003
# Epoch: 49, Step: 2400, Average Loss: 0.000000
# Epoch: 49, Step: 2500, Average Loss: 0.000000
# Epoch: 49, Step: 2600, Average Loss: 0.000000
# Epoch: 49, Step: 2700, Average Loss: 0.000000
# Epoch: 49, Step: 2800, Average Loss: 0.000001
# Epoch: 49, Step: 2900, Average Loss: 0.000106
# Epoch: 49, Step: 3000, Average Loss: 0.000000
# Epoch: 49, Step: 3100, Average Loss: 0.000000
# Epoch: 49, Step: 3200, Average Loss: 0.000001
# Epoch: 49, Step: 3300, Average Loss: 0.000000
# Epoch: 49, Validation Loss: 0.000405
